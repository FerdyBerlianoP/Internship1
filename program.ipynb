# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from datetime import datetime

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (01 Juli 2021).xlsx"
df=pd.read_excel(path)
df
# Out:
#      KODE KELURAHAN   WILAYAH KOTA          KECAMATAN          KELURAHAN  \
# 0               NaN            NaN                NaN              TOTAL
# 1      3.172051e+09  JAKARTA UTARA         PADEMANGAN              ANCOL
# 2      3.173041e+09  JAKARTA BARAT            TAMBORA              ANGKE
# 3      3.175041e+09  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG
# 4      3.175031e+09  JAKARTA TIMUR         JATINEGARA        BALI MESTER
# ..              ...            ...                ...                ...
# 263    3.175011e+09  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN
# 264    3.175011e+09  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA
# 265    3.171031e+09  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG
# 266    3.172021e+09  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS
# 267    3.173021e+09  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA
#
#      SASARAN  BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# ...

# %%
df.drop(['KODE KELURAHAN'], axis=1,inplace=True)
df
# Out:
#       WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# 0              NaN                NaN              TOTAL  7739060
# 1    JAKARTA UTARA         PADEMANGAN              ANCOL    20393
# 2    JAKARTA BARAT            TAMBORA              ANGKE    25785
# 3    JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    25158
# 4    JAKARTA TIMUR         JATINEGARA        BALI MESTER     8683
# ..             ...                ...                ...      ...
# 263  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    29303
# 264  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    24728
# 265  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    25622
# 266  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    38194
# 267  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    34170
#
#      BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  TOTAL VAKSIN\nDIBERIKAN  \
# 0         5041111          2696017          1181740                  3877757
# ...

# %%
df.dtypes
# Out:
# WILAYAH KOTA                                object
# KECAMATAN                                   object
# KELURAHAN                                   object
# SASARAN                                      int64
# BELUM VAKSIN                                 int64
# JUMLAH\nDOSIS 1                              int64
# JUMLAH\nDOSIS 2                              int64
# TOTAL VAKSIN\nDIBERIKAN                      int64
# LANSIA\nDOSIS 1                              int64
# LANSIA\nDOSIS 2                              int64
# LANSIA TOTAL \nVAKSIN DIBERIKAN              int64
# PELAYAN PUBLIK\nDOSIS 1                      int64
# PELAYAN PUBLIK\nDOSIS 2                      int64
# PELAYAN PUBLIK TOTAL\nVAKSIN DIBERIKAN       int64
# GOTONG ROYONG\nDOSIS 1                       int64
# GOTONG ROYONG\nDOSIS 2                       int64
# GOTONG ROYONG TOTAL\nVAKSIN DIBERIKAN        int64
# TENAGA KESEHATAN\nDOSIS 1                    int64
# ...

# %%
juli1=df.loc[1:]
juli1
# Out:
#       WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# 1    JAKARTA UTARA         PADEMANGAN              ANCOL    20393
# 2    JAKARTA BARAT            TAMBORA              ANGKE    25785
# 3    JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    25158
# 4    JAKARTA TIMUR         JATINEGARA        BALI MESTER     8683
# 5    JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    22768
# ..             ...                ...                ...      ...
# 263  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    29303
# 264  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    24728
# 265  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    25622
# 266  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    38194
# 267  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    34170
#
#      BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  TOTAL VAKSIN\nDIBERIKAN  \
# 1           13272             7114             3287                    10401
# ...

# %%
x=datetime(2021,7,1)
juli1['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli1
# Out:
#       WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# 1    JAKARTA UTARA         PADEMANGAN              ANCOL    20393
# 2    JAKARTA BARAT            TAMBORA              ANGKE    25785
# 3    JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    25158
# 4    JAKARTA TIMUR         JATINEGARA        BALI MESTER     8683
# 5    JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    22768
# ..             ...                ...                ...      ...
# 263  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    29303
# 264  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    24728
# 265  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    25622
# 266  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    38194
# 267  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    34170
#
#      BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  TOTAL VAKSIN\nDIBERIKAN  \
# 1           13272             7114             3287                    10401
# ...

# %%
juli1.set_index(juli1.pop('TANGGAL'), inplace=True)
juli1
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-01  JAKARTA UTARA         PADEMANGAN              ANCOL    20393
# 2021-07-01  JAKARTA BARAT            TAMBORA              ANGKE    25785
# 2021-07-01  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    25158
# 2021-07-01  JAKARTA TIMUR         JATINEGARA        BALI MESTER     8683
# 2021-07-01  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    22768
# ...                   ...                ...                ...      ...
# 2021-07-01  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    29303
# 2021-07-01  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    24728
# 2021-07-01  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    25622
# 2021-07-01  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    38194
# 2021-07-01  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    34170
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
juli1.isna().sum()
# Out:
# WILAYAH KOTA                                0
# KECAMATAN                                   0
# KELURAHAN                                   0
# SASARAN                                     0
# BELUM VAKSIN                                0
# JUMLAH\nDOSIS 1                             0
# JUMLAH\nDOSIS 2                             0
# TOTAL VAKSIN\nDIBERIKAN                     0
# LANSIA\nDOSIS 1                             0
# LANSIA\nDOSIS 2                             0
# LANSIA TOTAL \nVAKSIN DIBERIKAN             0
# PELAYAN PUBLIK\nDOSIS 1                     0
# PELAYAN PUBLIK\nDOSIS 2                     0
# PELAYAN PUBLIK TOTAL\nVAKSIN DIBERIKAN      0
# GOTONG ROYONG\nDOSIS 1                      0
# GOTONG ROYONG\nDOSIS 2                      0
# GOTONG ROYONG TOTAL\nVAKSIN DIBERIKAN       0
# TENAGA KESEHATAN\nDOSIS 1                   0
# TENAGA KESEHATAN\nDOSIS 2                   0
# TENAGA KESEHATAN TOTAL\nVAKSIN DIBERIKAN    0
# dtype: int64

# %%
juli1.shape
# Out:
# (267, 20)

# %%
juli1.describe()
# Out:
#              SASARAN  BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# count     267.000000    267.000000       267.000000       267.000000
# mean    28985.243446  18880.565543     10097.441948      4425.992509
# std     17092.255470  11843.484293      5646.358096      2424.003745
# min      1665.000000    443.000000       921.000000       558.000000
# 25%     17698.000000  11216.500000      6105.000000      2688.500000
# 50%     26178.000000  16813.000000      9202.000000      3957.000000
# 75%     36727.000000  23906.000000     12877.000000      5710.500000
# max    104630.000000  72832.000000     31788.000000     13463.000000
#
#        TOTAL VAKSIN\nDIBERIKAN  LANSIA\nDOSIS 1  LANSIA\nDOSIS 2  \
# count               267.000000       267.000000       267.000000
# mean              14523.434457      1883.419476      1681.921348
# std                7975.877249      1100.917323      1009.794469
# min                1489.000000       124.000000       107.000000
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (02 Juli 2021).xlsx"
df1=pd.read_excel(path)
df1
# Out:
#      KODE KELURAHAN   WILAYAH KOTA          KECAMATAN          KELURAHAN  \
# 0               NaN            NaN                NaN              TOTAL
# 1      3.172051e+09  JAKARTA UTARA         PADEMANGAN              ANCOL
# 2      3.173041e+09  JAKARTA BARAT            TAMBORA              ANGKE
# 3      3.175041e+09  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG
# 4      3.175031e+09  JAKARTA TIMUR         JATINEGARA        BALI MESTER
# ..              ...            ...                ...                ...
# 263    3.175011e+09  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN
# 264    3.175011e+09  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA
# 265    3.171031e+09  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG
# 266    3.172021e+09  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS
# 267    3.173021e+09  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA
#
#      SASARAN  BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# ...

# %%
df1.drop(['KODE KELURAHAN'],axis=1, inplace=True)
juli2=df1.loc[1:]
juli2
# Out:
#       WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# 1    JAKARTA UTARA         PADEMANGAN              ANCOL    20393
# 2    JAKARTA BARAT            TAMBORA              ANGKE    25785
# 3    JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    25158
# 4    JAKARTA TIMUR         JATINEGARA        BALI MESTER     8683
# 5    JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    22768
# ..             ...                ...                ...      ...
# 263  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    29303
# 264  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    24728
# 265  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    25622
# 266  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    38194
# 267  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    34170
#
#      BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  TOTAL VAKSIN\nDIBERIKAN  \
# 1           13163             7223             3290                    10513
# ...

# %%
x=datetime(2021,7,2)
juli2['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))

# %%
juli2.set_index(juli2.pop('TANGGAL'), inplace=True)
juli2
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-02  JAKARTA UTARA         PADEMANGAN              ANCOL    20393
# 2021-07-02  JAKARTA BARAT            TAMBORA              ANGKE    25785
# 2021-07-02  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    25158
# 2021-07-02  JAKARTA TIMUR         JATINEGARA        BALI MESTER     8683
# 2021-07-02  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    22768
# ...                   ...                ...                ...      ...
# 2021-07-02  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    29303
# 2021-07-02  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    24728
# 2021-07-02  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    25622
# 2021-07-02  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    38194
# 2021-07-02  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    34170
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
juli2.isna().sum()
# Out:
# WILAYAH KOTA                                0
# KECAMATAN                                   0
# KELURAHAN                                   0
# SASARAN                                     0
# BELUM VAKSIN                                0
# JUMLAH\nDOSIS 1                             0
# JUMLAH\nDOSIS 2                             0
# TOTAL VAKSIN\nDIBERIKAN                     0
# LANSIA\nDOSIS 1                             0
# LANSIA\nDOSIS 2                             0
# LANSIA TOTAL \nVAKSIN DIBERIKAN             0
# PELAYAN PUBLIK\nDOSIS 1                     0
# PELAYAN PUBLIK\nDOSIS 2                     0
# PELAYAN PUBLIK TOTAL\nVAKSIN DIBERIKAN      0
# GOTONG ROYONG\nDOSIS 1                      0
# GOTONG ROYONG\nDOSIS 2                      0
# GOTONG ROYONG TOTAL\nVAKSIN DIBERIKAN       0
# TENAGA KESEHATAN\nDOSIS 1                   0
# TENAGA KESEHATAN\nDOSIS 2                   0
# TENAGA KESEHATAN TOTAL\nVAKSIN DIBERIKAN    0
# dtype: int64

# %%
juli2.describe()
# Out:
#              SASARAN  BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# count     267.000000    267.000000       267.000000       267.000000
# mean    28985.243446  18682.176030     10295.692884      4433.797753
# std     17092.255470  11739.977817      5755.192756      2428.479871
# min      1665.000000    439.000000       937.000000       558.000000
# 25%     17698.000000  11113.500000      6250.500000      2693.000000
# 50%     26178.000000  16705.000000      9378.000000      3966.000000
# 75%     36727.000000  23671.500000     13093.500000      5724.000000
# max    104630.000000  72258.000000     32362.000000     13466.000000
#
#        TOTAL VAKSIN\nDIBERIKAN  LANSIA\nDOSIS 1  LANSIA\nDOSIS 2  \
# count               267.000000       267.000000       267.000000
# mean              14729.490637      1886.966292      1682.397004
# std                8088.378054      1102.911244      1009.949370
# min                1505.000000       124.000000       107.000000
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (03 Juli 2021).xlsx"
df2=pd.read_excel(path)
df2
# Out:
#       WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# 0              NaN                NaN              TOTAL  7739060
# 1    JAKARTA UTARA         PADEMANGAN              ANCOL    20393
# 2    JAKARTA BARAT            TAMBORA              ANGKE    25785
# 3    JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    25158
# 4    JAKARTA TIMUR         JATINEGARA        BALI MESTER     8683
# ..             ...                ...                ...      ...
# 263  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    29303
# 264  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    24728
# 265  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    25622
# 266  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    38194
# 267  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    34170
#
#      BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  TOTAL VAKSIN\nDIBERIKAN  \
# 0         5041111          2696017          1181740                  3877757
# ...

# %%
df2.drop(['KODE KELURAHAN'],axis=1, inplace=True)
juli3=df2.loc[1:]
juli3
# Out:
#       WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# 1    JAKARTA UTARA         PADEMANGAN              ANCOL    20393
# 2    JAKARTA BARAT            TAMBORA              ANGKE    25785
# 3    JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    25158
# 4    JAKARTA TIMUR         JATINEGARA        BALI MESTER     8683
# 5    JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    22768
# ..             ...                ...                ...      ...
# 263  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    29303
# 264  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    24728
# 265  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    25622
# 266  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    38194
# 267  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    34170
#
#      BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  TOTAL VAKSIN\nDIBERIKAN  \
# 1           13065             7321             3297                    10618
# ...

# %%
x=datetime(2021,7,3)
juli3['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli3.set_index(juli3.pop('TANGGAL'), inplace=True)
juli3
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-03  JAKARTA UTARA         PADEMANGAN              ANCOL    20393
# 2021-07-03  JAKARTA BARAT            TAMBORA              ANGKE    25785
# 2021-07-03  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    25158
# 2021-07-03  JAKARTA TIMUR         JATINEGARA        BALI MESTER     8683
# 2021-07-03  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    22768
# ...                   ...                ...                ...      ...
# 2021-07-03  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    29303
# 2021-07-03  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    24728
# 2021-07-03  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    25622
# 2021-07-03  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    38194
# 2021-07-03  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    34170
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
juli3.isna().sum()
# Out:
# WILAYAH KOTA                                0
# KECAMATAN                                   0
# KELURAHAN                                   0
# SASARAN                                     0
# BELUM VAKSIN                                0
# JUMLAH\nDOSIS 1                             0
# JUMLAH\nDOSIS 2                             0
# TOTAL VAKSIN\nDIBERIKAN                     0
# LANSIA\nDOSIS 1                             0
# LANSIA\nDOSIS 2                             0
# LANSIA TOTAL \nVAKSIN DIBERIKAN             0
# PELAYAN PUBLIK\nDOSIS 1                     0
# PELAYAN PUBLIK\nDOSIS 2                     0
# PELAYAN PUBLIK TOTAL\nVAKSIN DIBERIKAN      0
# GOTONG ROYONG\nDOSIS 1                      0
# GOTONG ROYONG\nDOSIS 2                      0
# GOTONG ROYONG TOTAL\nVAKSIN DIBERIKAN       0
# TENAGA KESEHATAN\nDOSIS 1                   0
# TENAGA KESEHATAN\nDOSIS 2                   0
# TENAGA KESEHATAN TOTAL\nVAKSIN DIBERIKAN    0
# dtype: int64

# %%
juli3.describe()
# Out:
#              SASARAN  BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# count     267.000000    267.000000       267.000000       267.000000
# mean    28985.243446  18529.232210     10448.501873      4438.400749
# std     17092.255470  11649.460032      5850.404810      2430.995127
# min      1665.000000    433.000000       950.000000       558.000000
# 25%     17698.000000  11019.500000      6321.500000      2697.000000
# 50%     26178.000000  16604.000000      9549.000000      3973.000000
# 75%     36727.000000  23476.500000     13320.500000      5732.500000
# max    104630.000000  71764.000000     32856.000000     13481.000000
#
#        TOTAL VAKSIN\nDIBERIKAN  LANSIA\nDOSIS 1  LANSIA\nDOSIS 2  \
# count               267.000000       267.000000       267.000000
# mean              14886.902622      1889.168539      1682.700375
# std                8185.010866      1104.170443      1010.060063
# min                1518.000000       124.000000       108.000000
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (04 Juli 2021).xlsx"
df3=pd.read_excel(path)
df3
# Out:
#      KODE KELURAHAN   WILAYAH KOTA          KECAMATAN          KELURAHAN  \
# 0               NaN            NaN                NaN              TOTAL
# 1      3.172051e+09  JAKARTA UTARA         PADEMANGAN              ANCOL
# 2      3.173041e+09  JAKARTA BARAT            TAMBORA              ANGKE
# 3      3.175041e+09  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG
# 4      3.175031e+09  JAKARTA TIMUR         JATINEGARA        BALI MESTER
# ..              ...            ...                ...                ...
# 263    3.175011e+09  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN
# 264    3.175011e+09  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA
# 265    3.171031e+09  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG
# 266    3.172021e+09  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS
# 267    3.173021e+09  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA
#
#      SASARAN  BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# ...

# %%
df3.drop(['KODE KELURAHAN'], axis=1,inplace=True)
juli4=df2.loc[1:]
juli4
# Out:
#       WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# 1    JAKARTA UTARA         PADEMANGAN              ANCOL    20393
# 2    JAKARTA BARAT            TAMBORA              ANGKE    25785
# 3    JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    25158
# 4    JAKARTA TIMUR         JATINEGARA        BALI MESTER     8683
# 5    JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    22768
# ..             ...                ...                ...      ...
# 263  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    29303
# 264  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    24728
# 265  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    25622
# 266  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    38194
# 267  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    34170
#
#      BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  TOTAL VAKSIN\nDIBERIKAN  \
# 1           13065             7321             3297                    10618
# ...

# %%
x=datetime(2021,7,4)
juli4['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli4.set_index(juli4.pop('TANGGAL'), inplace=True)
juli4
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-04  JAKARTA UTARA         PADEMANGAN              ANCOL    20393
# 2021-07-04  JAKARTA BARAT            TAMBORA              ANGKE    25785
# 2021-07-04  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    25158
# 2021-07-04  JAKARTA TIMUR         JATINEGARA        BALI MESTER     8683
# 2021-07-04  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    22768
# ...                   ...                ...                ...      ...
# 2021-07-04  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    29303
# 2021-07-04  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    24728
# 2021-07-04  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    25622
# 2021-07-04  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    38194
# 2021-07-04  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    34170
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
juli4.isna().sum()
# Out:
# WILAYAH KOTA                                0
# KECAMATAN                                   0
# KELURAHAN                                   0
# SASARAN                                     0
# BELUM VAKSIN                                0
# JUMLAH\nDOSIS 1                             0
# JUMLAH\nDOSIS 2                             0
# TOTAL VAKSIN\nDIBERIKAN                     0
# LANSIA\nDOSIS 1                             0
# LANSIA\nDOSIS 2                             0
# LANSIA TOTAL \nVAKSIN DIBERIKAN             0
# PELAYAN PUBLIK\nDOSIS 1                     0
# PELAYAN PUBLIK\nDOSIS 2                     0
# PELAYAN PUBLIK TOTAL\nVAKSIN DIBERIKAN      0
# GOTONG ROYONG\nDOSIS 1                      0
# GOTONG ROYONG\nDOSIS 2                      0
# GOTONG ROYONG TOTAL\nVAKSIN DIBERIKAN       0
# TENAGA KESEHATAN\nDOSIS 1                   0
# TENAGA KESEHATAN\nDOSIS 2                   0
# TENAGA KESEHATAN TOTAL\nVAKSIN DIBERIKAN    0
# dtype: int64

# %%
juli4.shape
# Out:
# (267, 20)

# %%
juli4.describe()
# Out:
#              SASARAN  BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# count     267.000000    267.000000       267.000000       267.000000
# mean    28985.243446  18529.232210     10448.501873      4438.400749
# std     17092.255470  11649.460032      5850.404810      2430.995127
# min      1665.000000    433.000000       950.000000       558.000000
# 25%     17698.000000  11019.500000      6321.500000      2697.000000
# 50%     26178.000000  16604.000000      9549.000000      3973.000000
# 75%     36727.000000  23476.500000     13320.500000      5732.500000
# max    104630.000000  71764.000000     32856.000000     13481.000000
#
#        TOTAL VAKSIN\nDIBERIKAN  LANSIA\nDOSIS 1  LANSIA\nDOSIS 2  \
# count               267.000000       267.000000       267.000000
# mean              14886.902622      1889.168539      1682.700375
# std                8185.010866      1104.170443      1010.060063
# min                1518.000000       124.000000       108.000000
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (05 Juli 2021).xlsx"
df4=pd.read_excel(path)
df4
# Out:
#      KODE KELURAHAN   WILAYAH KOTA          KECAMATAN          KELURAHAN  \
# 0               NaN            NaN                NaN              TOTAL
# 1      3.172051e+09  JAKARTA UTARA         PADEMANGAN              ANCOL
# 2      3.173041e+09  JAKARTA BARAT            TAMBORA              ANGKE
# 3      3.175041e+09  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG
# 4      3.175031e+09  JAKARTA TIMUR         JATINEGARA        BALI MESTER
# ..              ...            ...                ...                ...
# 263    3.175011e+09  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN
# 264    3.175011e+09  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA
# 265    3.171031e+09  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG
# 266    3.172021e+09  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS
# 267    3.173021e+09  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA
#
#      SASARAN  BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# ...

# %%
df4.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli5=df4.loc[1:]
juli5
# Out:
#       WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# 1    JAKARTA UTARA         PADEMANGAN              ANCOL    23379
# 2    JAKARTA BARAT            TAMBORA              ANGKE    29230
# 3    JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    28803
# 4    JAKARTA TIMUR         JATINEGARA        BALI MESTER     9675
# 5    JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    25985
# ..             ...                ...                ...      ...
# 263  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33233
# 264  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    27995
# 265  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29260
# 266  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    43754
# 267  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38584
#
#      BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  TOTAL VAKSIN\nDIBERIKAN  \
# 1           15856             7523             3299                    10822
# ...

# %%
x=datetime(2021,7,5)
juli5['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli5.set_index(juli5.pop('TANGGAL'), inplace=True)
juli5
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-05  JAKARTA UTARA         PADEMANGAN              ANCOL    23379
# 2021-07-05  JAKARTA BARAT            TAMBORA              ANGKE    29230
# 2021-07-05  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    28803
# 2021-07-05  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9675
# 2021-07-05  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    25985
# ...                   ...                ...                ...      ...
# 2021-07-05  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33233
# 2021-07-05  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    27995
# 2021-07-05  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29260
# 2021-07-05  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    43754
# 2021-07-05  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38584
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
juli5.isna().sum()
# Out:
# WILAYAH KOTA                                0
# KECAMATAN                                   0
# KELURAHAN                                   0
# SASARAN                                     0
# BELUM VAKSIN                                0
# JUMLAH\nDOSIS 1                             0
# JUMLAH\nDOSIS 2                             0
# TOTAL VAKSIN\nDIBERIKAN                     0
# LANSIA\nDOSIS 1                             0
# LANSIA\nDOSIS 2                             0
# LANSIA TOTAL \nVAKSIN DIBERIKAN             0
# PELAYAN PUBLIK\nDOSIS 1                     0
# PELAYAN PUBLIK\nDOSIS 2                     0
# PELAYAN PUBLIK TOTAL\nVAKSIN DIBERIKAN      0
# GOTONG ROYONG\nDOSIS 1                      0
# GOTONG ROYONG\nDOSIS 2                      0
# GOTONG ROYONG TOTAL\nVAKSIN DIBERIKAN       0
# TENAGA KESEHATAN\nDOSIS 1                   0
# TENAGA KESEHATAN\nDOSIS 2                   0
# TENAGA KESEHATAN TOTAL\nVAKSIN DIBERIKAN    0
# ...

# %%
juli5.shape
# Out:
# (267, 23)

# %%
juli5.describe()
# Out:
#              SASARAN  BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# count     267.000000    267.000000       267.000000       267.000000
# mean    33005.674157  22283.599251     10722.074906      4445.194757
# std     19630.224479  14033.226045      6018.211509      2434.750836
# min      1918.000000    613.000000       968.000000       558.000000
# 25%     20146.000000  13314.500000      6471.500000      2698.500000
# 50%     30003.000000  19870.000000      9749.000000      3983.000000
# 75%     42019.500000  28361.000000     13628.000000      5740.000000
# max    121994.000000  88422.000000     33572.000000     13497.000000
#
#        TOTAL VAKSIN\nDIBERIKAN  LANSIA\nDOSIS 1  LANSIA\nDOSIS 2  \
# count               267.000000       267.000000       267.000000
# mean              15167.269663      1892.378277      1682.985019
# std                8354.662500      1106.419166      1010.143368
# min                1539.000000       124.000000       108.000000
# ...

# %%
juligabung= pd.concat([juli1,juli2,juli3,juli4,juli5], axis=0)
juligabung
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-01  JAKARTA UTARA         PADEMANGAN              ANCOL    20393
# 2021-07-01  JAKARTA BARAT            TAMBORA              ANGKE    25785
# 2021-07-01  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    25158
# 2021-07-01  JAKARTA TIMUR         JATINEGARA        BALI MESTER     8683
# 2021-07-01  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    22768
# ...                   ...                ...                ...      ...
# 2021-07-05  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33233
# 2021-07-05  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    27995
# 2021-07-05  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29260
# 2021-07-05  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    43754
# 2021-07-05  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38584
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
juligabung.shape
# Out:
# (1335, 23)

# %%
juligabung.head()
# Out:
#              WILAYAH KOTA    KECAMATAN     KELURAHAN  SASARAN  BELUM VAKSIN  \
# TANGGAL
# 2021-07-01  JAKARTA UTARA   PADEMANGAN         ANCOL    20393         13272
# 2021-07-01  JAKARTA BARAT      TAMBORA         ANGKE    25785         16477
# 2021-07-01  JAKARTA TIMUR  KRAMAT JATI  BALE KAMBANG    25158         18849
# 2021-07-01  JAKARTA TIMUR   JATINEGARA   BALI MESTER     8683          5743
# 2021-07-01  JAKARTA TIMUR     CIPAYUNG    BAMBU APUS    22768         15407
#
#             JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  TOTAL VAKSIN\nDIBERIKAN  \
# TANGGAL
# 2021-07-01             7114             3287                    10401
# 2021-07-01             9299             3221                    12520
# 2021-07-01             6301             2644                     8945
# 2021-07-01             2937             1517                     4454
# 2021-07-01             7357             3985                    11342
#
#             LANSIA\nDOSIS 1  LANSIA\nDOSIS 2  ...  \
# ...

# %%
juligabung.tail()
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-05  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33233
# 2021-07-05  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    27995
# 2021-07-05  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29260
# 2021-07-05  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    43754
# 2021-07-05  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38584
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# 2021-07-05         21751            11482             5051
# 2021-07-05         18463             9532             3823
# 2021-07-05         21585             7675             2801
# 2021-07-05         29169            14585             5217
# 2021-07-05         26162            12422             4858
#
#             TOTAL VAKSIN\nDIBERIKAN  LANSIA\nDOSIS 1  LANSIA\nDOSIS 2  ...  \
# ...

# %%
juligabung.to_excel('juligabung.xlsx', index=False)

# %%
plt.figure(figsize = (20,20))
juligabung.plot.area("KELURAHAN",["JUMLAH\nDOSIS 1","JUMLAH\nDOSIS 2", "TOTAL VAKSIN\nDIBERIKAN"])
plt.show()

# %%
plt.figure(figsize = (10,10))
plt.xlabel("KELURAHAN")
plt.title("TOTAL VAKSIN\nDIBERIKAN")
plt.bar("KELURAHAN","TOTAL VAKSIN\nDIBERIKAN",data=juligabung)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from datetime import datetime

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (01 Juli 2021).xlsx"
df=pd.read_excel(path)
df
# Out:
#      KODE KELURAHAN   WILAYAH KOTA          KECAMATAN          KELURAHAN  \
# 0               NaN            NaN                NaN              TOTAL
# 1      3.172051e+09  JAKARTA UTARA         PADEMANGAN              ANCOL
# 2      3.173041e+09  JAKARTA BARAT            TAMBORA              ANGKE
# 3      3.175041e+09  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG
# 4      3.175031e+09  JAKARTA TIMUR         JATINEGARA        BALI MESTER
# ..              ...            ...                ...                ...
# 263    3.175011e+09  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN
# 264    3.175011e+09  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA
# 265    3.171031e+09  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG
# 266    3.172021e+09  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS
# 267    3.173021e+09  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA
#
#      SASARAN  BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# ...

# %%
df.drop(['KODE KELURAHAN'], axis=1,inplace=True)
df
# Out:
#       WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# 0              NaN                NaN              TOTAL  7739060
# 1    JAKARTA UTARA         PADEMANGAN              ANCOL    20393
# 2    JAKARTA BARAT            TAMBORA              ANGKE    25785
# 3    JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    25158
# 4    JAKARTA TIMUR         JATINEGARA        BALI MESTER     8683
# ..             ...                ...                ...      ...
# 263  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    29303
# 264  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    24728
# 265  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    25622
# 266  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    38194
# 267  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    34170
#
#      BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  TOTAL VAKSIN\nDIBERIKAN  \
# 0         5041111          2696017          1181740                  3877757
# ...

# %%
juli1=df.loc[1:]
juli1
# Out:
#       WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# 1    JAKARTA UTARA         PADEMANGAN              ANCOL    20393
# 2    JAKARTA BARAT            TAMBORA              ANGKE    25785
# 3    JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    25158
# 4    JAKARTA TIMUR         JATINEGARA        BALI MESTER     8683
# 5    JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    22768
# ..             ...                ...                ...      ...
# 263  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    29303
# 264  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    24728
# 265  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    25622
# 266  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    38194
# 267  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    34170
#
#      BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  TOTAL VAKSIN\nDIBERIKAN  \
# 1           13272             7114             3287                    10401
# ...

# %%
x=datetime(2021,7,1)
juli1['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli1
# Out:
#       WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# 1    JAKARTA UTARA         PADEMANGAN              ANCOL    20393
# 2    JAKARTA BARAT            TAMBORA              ANGKE    25785
# 3    JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    25158
# 4    JAKARTA TIMUR         JATINEGARA        BALI MESTER     8683
# 5    JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    22768
# ..             ...                ...                ...      ...
# 263  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    29303
# 264  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    24728
# 265  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    25622
# 266  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    38194
# 267  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    34170
#
#      BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  TOTAL VAKSIN\nDIBERIKAN  \
# 1           13272             7114             3287                    10401
# ...

# %%
juli1.set_index(juli1.pop('TANGGAL'), inplace=True)
juli1
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-01  JAKARTA UTARA         PADEMANGAN              ANCOL    20393
# 2021-07-01  JAKARTA BARAT            TAMBORA              ANGKE    25785
# 2021-07-01  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    25158
# 2021-07-01  JAKARTA TIMUR         JATINEGARA        BALI MESTER     8683
# 2021-07-01  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    22768
# ...                   ...                ...                ...      ...
# 2021-07-01  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    29303
# 2021-07-01  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    24728
# 2021-07-01  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    25622
# 2021-07-01  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    38194
# 2021-07-01  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    34170
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
juli1.shape
# Out:
# (267, 20)

# %%
juli1.describe()
# Out:
#              SASARAN  BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# count     267.000000    267.000000       267.000000       267.000000
# mean    28985.243446  18880.565543     10097.441948      4425.992509
# std     17092.255470  11843.484293      5646.358096      2424.003745
# min      1665.000000    443.000000       921.000000       558.000000
# 25%     17698.000000  11216.500000      6105.000000      2688.500000
# 50%     26178.000000  16813.000000      9202.000000      3957.000000
# 75%     36727.000000  23906.000000     12877.000000      5710.500000
# max    104630.000000  72832.000000     31788.000000     13463.000000
#
#        TOTAL VAKSIN\nDIBERIKAN  LANSIA\nDOSIS 1  LANSIA\nDOSIS 2  \
# count               267.000000       267.000000       267.000000
# mean              14523.434457      1883.419476      1681.921348
# std                7975.877249      1100.917323      1009.794469
# min                1489.000000       124.000000       107.000000
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (02 Juli 2021).xlsx"
df1=pd.read_excel(path)
df1
# Out:
#      KODE KELURAHAN   WILAYAH KOTA          KECAMATAN          KELURAHAN  \
# 0               NaN            NaN                NaN              TOTAL
# 1      3.172051e+09  JAKARTA UTARA         PADEMANGAN              ANCOL
# 2      3.173041e+09  JAKARTA BARAT            TAMBORA              ANGKE
# 3      3.175041e+09  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG
# 4      3.175031e+09  JAKARTA TIMUR         JATINEGARA        BALI MESTER
# ..              ...            ...                ...                ...
# 263    3.175011e+09  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN
# 264    3.175011e+09  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA
# 265    3.171031e+09  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG
# 266    3.172021e+09  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS
# 267    3.173021e+09  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA
#
#      SASARAN  BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# ...

# %%
df1.drop(['KODE KELURAHAN'],axis=1, inplace=True)
juli2=df1.loc[1:]
juli2
# Out:
#       WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# 1    JAKARTA UTARA         PADEMANGAN              ANCOL    20393
# 2    JAKARTA BARAT            TAMBORA              ANGKE    25785
# 3    JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    25158
# 4    JAKARTA TIMUR         JATINEGARA        BALI MESTER     8683
# 5    JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    22768
# ..             ...                ...                ...      ...
# 263  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    29303
# 264  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    24728
# 265  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    25622
# 266  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    38194
# 267  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    34170
#
#      BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  TOTAL VAKSIN\nDIBERIKAN  \
# 1           13163             7223             3290                    10513
# ...

# %%
x=datetime(2021,7,2)
juli2['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli2.set_index(juli2.pop('TANGGAL'), inplace=True)
juli2
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-02  JAKARTA UTARA         PADEMANGAN              ANCOL    20393
# 2021-07-02  JAKARTA BARAT            TAMBORA              ANGKE    25785
# 2021-07-02  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    25158
# 2021-07-02  JAKARTA TIMUR         JATINEGARA        BALI MESTER     8683
# 2021-07-02  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    22768
# ...                   ...                ...                ...      ...
# 2021-07-02  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    29303
# 2021-07-02  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    24728
# 2021-07-02  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    25622
# 2021-07-02  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    38194
# 2021-07-02  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    34170
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (03 Juli 2021).xlsx"
df2=pd.read_excel(path)
df2
# Out:
#      KODE KELURAHAN   WILAYAH KOTA          KECAMATAN          KELURAHAN  \
# 0               NaN            NaN                NaN              TOTAL
# 1      3.172051e+09  JAKARTA UTARA         PADEMANGAN              ANCOL
# 2      3.173041e+09  JAKARTA BARAT            TAMBORA              ANGKE
# 3      3.175041e+09  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG
# 4      3.175031e+09  JAKARTA TIMUR         JATINEGARA        BALI MESTER
# ..              ...            ...                ...                ...
# 263    3.175011e+09  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN
# 264    3.175011e+09  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA
# 265    3.171031e+09  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG
# 266    3.172021e+09  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS
# 267    3.173021e+09  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA
#
#      SASARAN  BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# ...

# %%
df2.drop(['KODE KELURAHAN'],axis=1, inplace=True)
juli3=df2.loc[1:]
juli3
# Out:
#       WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# 1    JAKARTA UTARA         PADEMANGAN              ANCOL    20393
# 2    JAKARTA BARAT            TAMBORA              ANGKE    25785
# 3    JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    25158
# 4    JAKARTA TIMUR         JATINEGARA        BALI MESTER     8683
# 5    JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    22768
# ..             ...                ...                ...      ...
# 263  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    29303
# 264  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    24728
# 265  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    25622
# 266  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    38194
# 267  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    34170
#
#      BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  TOTAL VAKSIN\nDIBERIKAN  \
# 1           13065             7321             3297                    10618
# ...

# %%
x=datetime(2021,7,3)
juli3['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli3.set_index(juli3.pop('TANGGAL'), inplace=True)
juli3
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-03  JAKARTA UTARA         PADEMANGAN              ANCOL    20393
# 2021-07-03  JAKARTA BARAT            TAMBORA              ANGKE    25785
# 2021-07-03  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    25158
# 2021-07-03  JAKARTA TIMUR         JATINEGARA        BALI MESTER     8683
# 2021-07-03  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    22768
# ...                   ...                ...                ...      ...
# 2021-07-03  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    29303
# 2021-07-03  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    24728
# 2021-07-03  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    25622
# 2021-07-03  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    38194
# 2021-07-03  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    34170
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (04 Juli 2021).xlsx"
df3=pd.read_excel(path)
df3
# Out:
#      KODE KELURAHAN   WILAYAH KOTA          KECAMATAN          KELURAHAN  \
# 0               NaN            NaN                NaN              TOTAL
# 1      3.172051e+09  JAKARTA UTARA         PADEMANGAN              ANCOL
# 2      3.173041e+09  JAKARTA BARAT            TAMBORA              ANGKE
# 3      3.175041e+09  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG
# 4      3.175031e+09  JAKARTA TIMUR         JATINEGARA        BALI MESTER
# ..              ...            ...                ...                ...
# 263    3.175011e+09  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN
# 264    3.175011e+09  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA
# 265    3.171031e+09  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG
# 266    3.172021e+09  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS
# 267    3.173021e+09  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA
#
#      SASARAN  BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# ...

# %%
df3.drop(['KODE KELURAHAN'], axis=1,inplace=True)
juli4=df2.loc[1:]
juli4
# Out:
#       WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# 1    JAKARTA UTARA         PADEMANGAN              ANCOL    20393
# 2    JAKARTA BARAT            TAMBORA              ANGKE    25785
# 3    JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    25158
# 4    JAKARTA TIMUR         JATINEGARA        BALI MESTER     8683
# 5    JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    22768
# ..             ...                ...                ...      ...
# 263  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    29303
# 264  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    24728
# 265  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    25622
# 266  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    38194
# 267  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    34170
#
#      BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  TOTAL VAKSIN\nDIBERIKAN  \
# 1           13065             7321             3297                    10618
# ...

# %%
x=datetime(2021,7,4)
juli4['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli4.set_index(juli4.pop('TANGGAL'), inplace=True)
juli4
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-04  JAKARTA UTARA         PADEMANGAN              ANCOL    20393
# 2021-07-04  JAKARTA BARAT            TAMBORA              ANGKE    25785
# 2021-07-04  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    25158
# 2021-07-04  JAKARTA TIMUR         JATINEGARA        BALI MESTER     8683
# 2021-07-04  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    22768
# ...                   ...                ...                ...      ...
# 2021-07-04  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    29303
# 2021-07-04  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    24728
# 2021-07-04  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    25622
# 2021-07-04  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    38194
# 2021-07-04  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    34170
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (05 Juli 2021).xlsx"
df4=pd.read_excel(path)
df4
# Out:
#      KODE KELURAHAN   WILAYAH KOTA          KECAMATAN          KELURAHAN  \
# 0               NaN            NaN                NaN              TOTAL
# 1      3.172051e+09  JAKARTA UTARA         PADEMANGAN              ANCOL
# 2      3.173041e+09  JAKARTA BARAT            TAMBORA              ANGKE
# 3      3.175041e+09  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG
# 4      3.175031e+09  JAKARTA TIMUR         JATINEGARA        BALI MESTER
# ..              ...            ...                ...                ...
# 263    3.175011e+09  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN
# 264    3.175011e+09  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA
# 265    3.171031e+09  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG
# 266    3.172021e+09  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS
# 267    3.173021e+09  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA
#
#      SASARAN  BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# ...

# %%
df4.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli5=df4.loc[1:]
juli5
# Out:
#       WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# 1    JAKARTA UTARA         PADEMANGAN              ANCOL    23379
# 2    JAKARTA BARAT            TAMBORA              ANGKE    29230
# 3    JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    28803
# 4    JAKARTA TIMUR         JATINEGARA        BALI MESTER     9675
# 5    JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    25985
# ..             ...                ...                ...      ...
# 263  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33233
# 264  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    27995
# 265  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29260
# 266  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    43754
# 267  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38584
#
#      BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  TOTAL VAKSIN\nDIBERIKAN  \
# 1           15856             7523             3299                    10822
# ...

# %%
x=datetime(2021,7,5)
juli5['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli5.set_index(juli5.pop('TANGGAL'), inplace=True)
juli5
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-05  JAKARTA UTARA         PADEMANGAN              ANCOL    23379
# 2021-07-05  JAKARTA BARAT            TAMBORA              ANGKE    29230
# 2021-07-05  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    28803
# 2021-07-05  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9675
# 2021-07-05  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    25985
# ...                   ...                ...                ...      ...
# 2021-07-05  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33233
# 2021-07-05  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    27995
# 2021-07-05  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29260
# 2021-07-05  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    43754
# 2021-07-05  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38584
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (06 Juli 2021).xlsx"
df5=pd.read_excel(path)
df5
# Out:
#      KODE KELURAHAN   WILAYAH KOTA          KECAMATAN          KELURAHAN  \
# 0               NaN            NaN                NaN              TOTAL
# 1      3.172051e+09  JAKARTA UTARA         PADEMANGAN              ANCOL
# 2      3.173041e+09  JAKARTA BARAT            TAMBORA              ANGKE
# 3      3.175041e+09  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG
# 4      3.175031e+09  JAKARTA TIMUR         JATINEGARA        BALI MESTER
# ..              ...            ...                ...                ...
# 263    3.175011e+09  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN
# 264    3.175011e+09  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA
# 265    3.171031e+09  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG
# 266    3.172021e+09  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS
# 267    3.173021e+09  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA
#
#      SASARAN  BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# ...

# %%
df5.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli6=df5.loc[1:]
juli6
# Out:
#       WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# 1    JAKARTA UTARA         PADEMANGAN              ANCOL    23379
# 2    JAKARTA BARAT            TAMBORA              ANGKE    29230
# 3    JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    28803
# 4    JAKARTA TIMUR         JATINEGARA        BALI MESTER     9675
# 5    JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    25985
# ..             ...                ...                ...      ...
# 263  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33233
# 264  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    27995
# 265  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29260
# 266  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    43754
# 267  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38584
#
#      BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  TOTAL VAKSIN\nDIBERIKAN  \
# 1           15752             7627             3303                    10930
# ...

# %%
x=datetime(2021,7,6)
juli6['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli6.set_index(juli6.pop('TANGGAL'), inplace=True)
juli6
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-06  JAKARTA UTARA         PADEMANGAN              ANCOL    23379
# 2021-07-06  JAKARTA BARAT            TAMBORA              ANGKE    29230
# 2021-07-06  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    28803
# 2021-07-06  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9675
# 2021-07-06  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    25985
# ...                   ...                ...                ...      ...
# 2021-07-06  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33233
# 2021-07-06  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    27995
# 2021-07-06  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29260
# 2021-07-06  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    43754
# 2021-07-06  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38584
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (07 Juli 2021).xlsx"
df6=pd.read_excel(path)
df6.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli7=df6.loc[1:]
x=datetime(2021,7,7)
juli7['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli7.set_index(juli7.pop('TANGGAL'), inplace=True)
juli7
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-07  JAKARTA UTARA         PADEMANGAN              ANCOL    23379
# 2021-07-07  JAKARTA BARAT            TAMBORA              ANGKE    29230
# 2021-07-07  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    28803
# 2021-07-07  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9675
# 2021-07-07  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    25985
# ...                   ...                ...                ...      ...
# 2021-07-07  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33233
# 2021-07-07  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    27995
# 2021-07-07  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29260
# 2021-07-07  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    43754
# 2021-07-07  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38584
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (08 Juli 2021).xlsx"
df7=pd.read_excel(path)
df7.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli8=df7.loc[1:]
x=datetime(2021,7,8)
juli8['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli8.set_index(juli8.pop('TANGGAL'), inplace=True)
juli8
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-08  JAKARTA UTARA         PADEMANGAN              ANCOL    23379
# 2021-07-08  JAKARTA BARAT            TAMBORA              ANGKE    29230
# 2021-07-08  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    28803
# 2021-07-08  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9675
# 2021-07-08  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    25985
# ...                   ...                ...                ...      ...
# 2021-07-08  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33233
# 2021-07-08  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    27995
# 2021-07-08  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29260
# 2021-07-08  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    43754
# 2021-07-08  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38584
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (09 Juli 2021).xlsx"
df8=pd.read_excel(path)
df8.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli9=df8.loc[1:]
x=datetime(2021,7,8)
juli9['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli9.set_index(juli9.pop('TANGGAL'), inplace=True)
juli9
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-08  JAKARTA UTARA         PADEMANGAN              ANCOL    23379
# 2021-07-08  JAKARTA BARAT            TAMBORA              ANGKE    29230
# 2021-07-08  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    28803
# 2021-07-08  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9675
# 2021-07-08  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    25985
# ...                   ...                ...                ...      ...
# 2021-07-08  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33233
# 2021-07-08  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    27995
# 2021-07-08  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29260
# 2021-07-08  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    43754
# 2021-07-08  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38584
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (10 Juli 2021).xlsx"
df9=pd.read_excel(path)
df9.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli10=df9.loc[1:]
x=datetime(2021,7,10)
juli10['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli10.set_index(juli10.pop('TANGGAL'), inplace=True)
juli10
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-10  JAKARTA UTARA         PADEMANGAN              ANCOL    23379
# 2021-07-10  JAKARTA BARAT            TAMBORA              ANGKE    29230
# 2021-07-10  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    28803
# 2021-07-10  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9675
# 2021-07-10  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    25985
# ...                   ...                ...                ...      ...
# 2021-07-10  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33233
# 2021-07-10  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    27995
# 2021-07-10  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29260
# 2021-07-10  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    43754
# 2021-07-10  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38584
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (11 Juli 2021).xlsx"
df10=pd.read_excel(path)
df10.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli11=df10.loc[1:]
x=datetime(2021,7,11)
juli11['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli11.set_index(juli11.pop('TANGGAL'), inplace=True)
juli11
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-11  JAKARTA UTARA         PADEMANGAN              ANCOL    23379
# 2021-07-11  JAKARTA BARAT            TAMBORA              ANGKE    29230
# 2021-07-11  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    28803
# 2021-07-11  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9675
# 2021-07-11  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    25985
# ...                   ...                ...                ...      ...
# 2021-07-11  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33233
# 2021-07-11  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    27995
# 2021-07-11  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29260
# 2021-07-11  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    43754
# 2021-07-11  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38584
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (12 Juli 2021).xlsx"
df11=pd.read_excel(path)
df11.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli12=df11.loc[1:]
x=datetime(2021,7,12)
juli12['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli12.set_index(juli12.pop('TANGGAL'), inplace=True)
juli12
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-12  JAKARTA UTARA         PADEMANGAN              ANCOL    23379
# 2021-07-12  JAKARTA BARAT            TAMBORA              ANGKE    29230
# 2021-07-12  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    28803
# 2021-07-12  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9675
# 2021-07-12  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    25985
# ...                   ...                ...                ...      ...
# 2021-07-12  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33233
# 2021-07-12  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    27995
# 2021-07-12  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29260
# 2021-07-12  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    43754
# 2021-07-12  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38584
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (13 Juli 2021).xlsx"
df12=pd.read_excel(path)
df12.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli13=df12.loc[1:]
x=datetime(2021,7,13)
juli13['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli13.set_index(juli13.pop('TANGGAL'), inplace=True)
juli13
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-13  JAKARTA UTARA         PADEMANGAN              ANCOL    23379
# 2021-07-13  JAKARTA BARAT            TAMBORA              ANGKE    29230
# 2021-07-13  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    28803
# 2021-07-13  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9675
# 2021-07-13  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    25985
# ...                   ...                ...                ...      ...
# 2021-07-13  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33233
# 2021-07-13  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    27995
# 2021-07-13  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29260
# 2021-07-13  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    43754
# 2021-07-13  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38584
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (14 Juli 2021).xlsx"
df13=pd.read_excel(path)
df13.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli14=df13.loc[1:]
x=datetime(2021,7,14)
juli14['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli14.set_index(juli14.pop('TANGGAL'), inplace=True)
juli14
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-14  JAKARTA UTARA         PADEMANGAN              ANCOL    23379
# 2021-07-14  JAKARTA BARAT            TAMBORA              ANGKE    29230
# 2021-07-14  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    28803
# 2021-07-14  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9675
# 2021-07-14  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    25985
# ...                   ...                ...                ...      ...
# 2021-07-14  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33233
# 2021-07-14  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    27995
# 2021-07-14  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29260
# 2021-07-14  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    43754
# 2021-07-14  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38584
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (15 Juli 2021).xlsx"
df14=pd.read_excel(path)
df14.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli15=df14.loc[1:]
x=datetime(2021,7,15)
juli15['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli15.set_index(juli15.pop('TANGGAL'), inplace=True)
juli15
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-15  JAKARTA UTARA         PADEMANGAN              ANCOL    23379
# 2021-07-15  JAKARTA BARAT            TAMBORA              ANGKE    29230
# 2021-07-15  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    28803
# 2021-07-15  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9675
# 2021-07-15  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    25985
# ...                   ...                ...                ...      ...
# 2021-07-15  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33233
# 2021-07-15  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    27995
# 2021-07-15  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29260
# 2021-07-15  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    43754
# 2021-07-15  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38584
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (16 Juli 2021).xlsx"
df15=pd.read_excel(path)
df15.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli16=df15.loc[1:]
x=datetime(2021,7,16)
juli16['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli16.set_index(juli16.pop('TANGGAL'), inplace=True)
juli16
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-16  JAKARTA UTARA         PADEMANGAN              ANCOL    23379
# 2021-07-16  JAKARTA BARAT            TAMBORA              ANGKE    29230
# 2021-07-16  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    28803
# 2021-07-16  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9675
# 2021-07-16  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    25985
# ...                   ...                ...                ...      ...
# 2021-07-16  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33233
# 2021-07-16  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    27995
# 2021-07-16  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29260
# 2021-07-16  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    43754
# 2021-07-16  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38584
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (17 Juli 2021).xlsx"
df16=pd.read_excel(path)
df16.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli17=df16.loc[1:]
x=datetime(2021,7,17)
juli17['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli17.set_index(juli17.pop('TANGGAL'), inplace=True)
juli17
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-17  JAKARTA UTARA         PADEMANGAN              ANCOL    23379
# 2021-07-17  JAKARTA BARAT            TAMBORA              ANGKE    29230
# 2021-07-17  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    28803
# 2021-07-17  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9675
# 2021-07-17  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    25985
# ...                   ...                ...                ...      ...
# 2021-07-17  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33233
# 2021-07-17  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    27995
# 2021-07-17  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29260
# 2021-07-17  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    43754
# 2021-07-17  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38584
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (18 Juli 2021).xlsx"
df17=pd.read_excel(path)
df17.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli18=df17.loc[1:]
x=datetime(2021,7,18)
juli18['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli18.set_index(juli18.pop('TANGGAL'), inplace=True)
juli18
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-18  JAKARTA UTARA         PADEMANGAN              ANCOL    24516
# 2021-07-18  JAKARTA BARAT            TAMBORA              ANGKE    29988
# 2021-07-18  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29564
# 2021-07-18  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9926
# 2021-07-18  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26760
# ...                   ...                ...                ...      ...
# 2021-07-18  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    34205
# 2021-07-18  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28777
# 2021-07-18  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29932
# 2021-07-18  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    45436
# 2021-07-18  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    39811
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (20 Juli 2021).xlsx"
df19=pd.read_excel(path)
df19.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli20=df19.loc[1:]
x=datetime(2021,7,20)
juli20['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli20.set_index(juli20.pop('TANGGAL'), inplace=True)
juli20
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-20  JAKARTA UTARA         PADEMANGAN              ANCOL    24516
# 2021-07-20  JAKARTA BARAT            TAMBORA              ANGKE    29988
# 2021-07-20  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29564
# 2021-07-20  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9926
# 2021-07-20  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26760
# ...                   ...                ...                ...      ...
# 2021-07-20  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    34205
# 2021-07-20  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28777
# 2021-07-20  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29932
# 2021-07-20  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    45436
# 2021-07-20  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    39811
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (21 Juli 2021).xlsx"
df20=pd.read_excel(path)
df20.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli21=df20.loc[1:]
x=datetime(2021,7,21)
juli21['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli21.set_index(juli21.pop('TANGGAL'), inplace=True)
juli21
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-21  JAKARTA UTARA         PADEMANGAN              ANCOL    24516
# 2021-07-21  JAKARTA BARAT            TAMBORA              ANGKE    29988
# 2021-07-21  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29564
# 2021-07-21  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9926
# 2021-07-21  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26760
# ...                   ...                ...                ...      ...
# 2021-07-21  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    34205
# 2021-07-21  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28777
# 2021-07-21  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29932
# 2021-07-21  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    45436
# 2021-07-21  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    39811
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (22 Juli 2021).xlsx"
df21=pd.read_excel(path)
df21.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli22=df21.loc[1:]
x=datetime(2021,7,22)
juli22['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli22.set_index(juli22.pop('TANGGAL'), inplace=True)
juli22
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-22  JAKARTA UTARA         PADEMANGAN              ANCOL    24516
# 2021-07-22  JAKARTA BARAT            TAMBORA              ANGKE    29988
# 2021-07-22  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29564
# 2021-07-22  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9926
# 2021-07-22  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26760
# ...                   ...                ...                ...      ...
# 2021-07-22  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    34205
# 2021-07-22  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28777
# 2021-07-22  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29932
# 2021-07-22  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    45436
# 2021-07-22  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    39811
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (23 Juli 2021).xlsx"
df22=pd.read_excel(path)
df22.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli23=df22.loc[1:]
x=datetime(2021,7,23)
juli23['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli23.set_index(juli23.pop('TANGGAL'), inplace=True)
juli23
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-23  JAKARTA UTARA         PADEMANGAN              ANCOL    24516
# 2021-07-23  JAKARTA BARAT            TAMBORA              ANGKE    29988
# 2021-07-23  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29564
# 2021-07-23  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9926
# 2021-07-23  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26760
# ...                   ...                ...                ...      ...
# 2021-07-23  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    34205
# 2021-07-23  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28777
# 2021-07-23  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29932
# 2021-07-23  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    45436
# 2021-07-23  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    39811
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (24 Juli 2021).xlsx"
df23=pd.read_excel(path)
df23.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli24=df23.loc[1:]
x=datetime(2021,7,24)
juli24['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli24.set_index(juli24.pop('TANGGAL'), inplace=True)
juli24
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-24  JAKARTA UTARA         PADEMANGAN              ANCOL    24516
# 2021-07-24  JAKARTA BARAT            TAMBORA              ANGKE    29988
# 2021-07-24  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29564
# 2021-07-24  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9926
# 2021-07-24  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26760
# ...                   ...                ...                ...      ...
# 2021-07-24  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    34205
# 2021-07-24  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28777
# 2021-07-24  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29932
# 2021-07-24  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    45436
# 2021-07-24  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    39811
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (25 Juli 2021).xlsx"
df24=pd.read_excel(path)
df24.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli25=df24.loc[1:]
x=datetime(2021,7,25)
juli25['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli25.set_index(juli25.pop('TANGGAL'), inplace=True)
juli25
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-25  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-07-25  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-07-25  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-07-25  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-07-25  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-07-25  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-07-25  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-07-25  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-07-25  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-07-25  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (26 Juli 2021).xlsx"
df25=pd.read_excel(path)
df25.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli26=df25.loc[1:]
x=datetime(2021,7,26)
juli26['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli26.set_index(juli26.pop('TANGGAL'), inplace=True)
juli26
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-26  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-07-26  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-07-26  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-07-26  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-07-26  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-07-26  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-07-26  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-07-26  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-07-26  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-07-26  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (27 Juli 2021).xlsx"
df26=pd.read_excel(path)
df26.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli27=df26.loc[1:]
x=datetime(2021,7,27)
juli27['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli27.set_index(juli27.pop('TANGGAL'), inplace=True)
juli27
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-27  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-07-27  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-07-27  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-07-27  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-07-27  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-07-27  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-07-27  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-07-27  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-07-27  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-07-27  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (28 Juli 2021).xlsx"
df27=pd.read_excel(path)
df27.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli28=df27.loc[1:]
x=datetime(2021,7,28)
juli28['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli28.set_index(juli28.pop('TANGGAL'), inplace=True)
juli28
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-28  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-07-28  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-07-28  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-07-28  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-07-28  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-07-28  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-07-28  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-07-28  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-07-28  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-07-28  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (29 Juli 2021).xlsx"
df28=pd.read_excel(path)
df28.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli29=df28.loc[1:]
x=datetime(2021,7,29)
juli29['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli29.set_index(juli29.pop('TANGGAL'), inplace=True)
juli29
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-29  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-07-29  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-07-29  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-07-29  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-07-29  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-07-29  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-07-29  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-07-29  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-07-29  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-07-29  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (30 Juli 2021).xlsx"
df29=pd.read_excel(path)
df29.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli30=df29.loc[1:]
x=datetime(2021,7,30)
juli30['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli30.set_index(juli30.pop('TANGGAL'), inplace=True)
juli30
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-30  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-07-30  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-07-30  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-07-30  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-07-30  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-07-30  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-07-30  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-07-30  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-07-30  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-07-30  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Juli/Data Vaksinasi Berbasis Kelurahan (31 Juli 2021).xlsx"
df30=pd.read_excel(path)
df30.drop(['KODE KELURAHAN'],axis=1,inplace=True)
juli31=df30.loc[1:]
x=datetime(2021,7,31)
juli31['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
juli31.set_index(juli31.pop('TANGGAL'), inplace=True)
juli31
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-31  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-07-31  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-07-31  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-07-31  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-07-31  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-07-31  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-07-31  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-07-31  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-07-31  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-07-31  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
juligabung=pd.concat([juli1,juli2,juli3,juli4,juli5,juli6,juli7,juli8,juli9,juli10,juli11,juli13,juli14,juli15,juli16,
                      juli17,juli18,juli20,juli21,juli22,juli23,juli24,juli25,juli26,juli27,juli28,juli29,juli30,juli31],axis=0)
juligabung
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-01  JAKARTA UTARA         PADEMANGAN              ANCOL    20393
# 2021-07-01  JAKARTA BARAT            TAMBORA              ANGKE    25785
# 2021-07-01  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    25158
# 2021-07-01  JAKARTA TIMUR         JATINEGARA        BALI MESTER     8683
# 2021-07-01  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    22768
# ...                   ...                ...                ...      ...
# 2021-07-31  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-07-31  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-07-31  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-07-31  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-07-31  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
juligabung.shape
# Out:
# (7743, 26)

# %%
juligabung.describe()
# Out:
#              SASARAN  BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# count    7743.000000   7743.000000      7743.000000      7743.000000
# mean    32801.615007  19641.139352     13159.453958      4777.763399
# std     19638.148330  12588.490233      7926.191478      2689.827750
# min      1665.000000    414.000000       921.000000       558.000000
# 25%     19869.000000  11473.000000      7762.500000      2811.000000
# 50%     29730.000000  17721.000000     11700.000000      4282.000000
# 75%     41618.500000  25278.000000     17078.500000      6162.000000
# max    137086.000000  91239.000000     60238.000000     17952.000000
#
#        TOTAL VAKSIN\nDIBERIKAN  LANSIA\nDOSIS 1  LANSIA\nDOSIS 2  \
# count              7743.000000      7743.000000      7743.000000
# mean              17937.217358      1889.786129      1665.828103
# std               10447.537278      1092.771695       991.611281
# min                1489.000000       118.000000       103.000000
# ...

# %%
juligabung.isna().sum()
# Out:
# WILAYAH KOTA                                   0
# KECAMATAN                                      0
# KELURAHAN                                      0
# SASARAN                                        0
# BELUM VAKSIN                                   0
# JUMLAH\nDOSIS 1                                0
# JUMLAH\nDOSIS 2                                0
# TOTAL VAKSIN\nDIBERIKAN                        0
# LANSIA\nDOSIS 1                                0
# LANSIA\nDOSIS 2                                0
# LANSIA TOTAL \nVAKSIN DIBERIKAN                0
# PELAYAN PUBLIK\nDOSIS 1                        0
# PELAYAN PUBLIK\nDOSIS 2                        0
# PELAYAN PUBLIK TOTAL\nVAKSIN DIBERIKAN         0
# GOTONG ROYONG\nDOSIS 1                         0
# GOTONG ROYONG\nDOSIS 2                         0
# GOTONG ROYONG TOTAL\nVAKSIN DIBERIKAN          0
# TENAGA KESEHATAN\nDOSIS 1                      0
# TENAGA KESEHATAN\nDOSIS 2                      0
# ...

# %%
juligabung.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7743 entries, 2021-07-01 to 2021-07-31
# Data columns (total 26 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   WILAYAH KOTA                             7743 non-null   object
#  1   KECAMATAN                                7743 non-null   object
#  2   KELURAHAN                                7743 non-null   object
#  3   SASARAN                                  7743 non-null   int64
#  4   BELUM VAKSIN                             7743 non-null   int64
#  5   JUMLAH
# DOSIS 1                           7743 non-null   int64
#  6   JUMLAH
# DOSIS 2                           7743 non-null   int64
#  7   TOTAL VAKSIN
# DIBERIKAN                   7743 non-null   int64
#  8   LANSIA
# DOSIS 1                           7743 non-null   int64
#  9   LANSIA
# DOSIS 2                           7743 non-null   int64
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (01 Agustus 2021).xlsx"
agus1=pd.read_excel(path)
agus1.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus1=agus1.loc[1:]
x=datetime(2021,8,1)
agustus1['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus1.set_index(agustus1.pop('TANGGAL'), inplace=True)
agustus1
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-01  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-01  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-01  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-01  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-01  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-01  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-01  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-01  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-01  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-01  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (02 Agustus 2021).xlsx"
agus2=pd.read_excel(path)
agus2.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus2=agus2.loc[1:]
x=datetime(2021,8,2)
agustus2['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus2.set_index(agustus2.pop('TANGGAL'), inplace=True)
agustus2
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-02  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-02  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-02  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-02  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-02  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-02  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-02  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-02  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-02  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-02  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (03 Agustus 2021).xlsx"
agus3=pd.read_excel(path)
agus3.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus3=agus3.loc[1:]
x=datetime(2021,8,3)
agustus3['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus3.set_index(agustus3.pop('TANGGAL'), inplace=True)
agustus3
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-03  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-03  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-03  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-03  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-03  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-03  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-03  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-03  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-03  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-03  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (04 Agustus 2021).xlsx"
agus4=pd.read_excel(path)
agus4.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus4=agus4.loc[1:]
x=datetime(2021,8,4)
agustus4['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus4.set_index(agustus4.pop('TANGGAL'), inplace=True)
agustus4
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-04  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-04  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-04  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-04  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-04  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-04  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-04  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-04  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-04  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-04  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (05 Agustus 2021).xlsx"
agus5=pd.read_excel(path)
agus5.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus5=agus5.loc[1:]
x=datetime(2021,8,5)
agustus5['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus5.set_index(agustus5.pop('TANGGAL'), inplace=True)
agustus5
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-05  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-05  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-05  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-05  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-05  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-05  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-05  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-05  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-05  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-05  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (06 Agustus 2021).xlsx"
agus6=pd.read_excel(path)
agus6.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus6=agus6.loc[1:]
x=datetime(2021,8,6)
agustus6['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus6.set_index(agustus6.pop('TANGGAL'), inplace=True)
agustus6
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-06  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-06  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-06  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-06  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-06  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-06  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-06  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-06  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-06  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-06  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (07 Agustus 2021).xlsx"
agus7=pd.read_excel(path)
agus7.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus7=agus7.loc[1:]
x=datetime(2021,8,7)
agustus7['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus7.set_index(agustus7.pop('TANGGAL'), inplace=True)
agustus7
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-07  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-07  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-07  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-07  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-07  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-07  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-07  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-07  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-07  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-07  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (08 Agustus 2021).xlsx"
agus8=pd.read_excel(path)
agus8.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus8=agus8.loc[1:]
x=datetime(2021,8,8)
agustus8['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus8.set_index(agustus8.pop('TANGGAL'), inplace=True)
agustus8
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-08  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-08  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-08  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-08  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-08  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-08  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-08  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-08  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-08  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-08  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (09 Agustus 2021).xlsx"
agus9=pd.read_excel(path)
agus9.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus9=agus9.loc[1:]
x=datetime(2021,8,9)
agustus9['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus9.set_index(agustus9.pop('TANGGAL'), inplace=True)
agustus9
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-09  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-09  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-09  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-09  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-09  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-09  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-09  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-09  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-09  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-09  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (10 Agustus 2021).xlsx"
agus10=pd.read_excel(path)
agus10.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus10=agus10.loc[1:]
x=datetime(2021,8,10)
agustus10['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus10.set_index(agustus10.pop('TANGGAL'), inplace=True)
agustus10
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-10  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-10  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-10  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-10  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-10  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-10  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-10  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-10  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-10  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-10  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (11 Agustus 2021).xlsx"
agus11=pd.read_excel(path)
agus11.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus11=agus11.loc[1:]
x=datetime(2021,8,11)
agustus11['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus11.set_index(agustus11.pop('TANGGAL'), inplace=True)
agustus11
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-11  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-11  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-11  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-11  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-11  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-11  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-11  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-11  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-11  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-11  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (12 Agustus 2021).xlsx"
agus12=pd.read_excel(path)
agus12.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus12=agus12.loc[1:]
x=datetime(2021,8,12)
agustus12['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus12.set_index(agustus12.pop('TANGGAL'), inplace=True)
agustus12
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-12  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-12  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-12  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-12  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-12  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-12  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-12  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-12  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-12  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-12  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (13 Agustus 2021).xlsx"
agus13=pd.read_excel(path)
agus13.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus13=agus13.loc[1:]
x=datetime(2021,8,13)
agustus13['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus13.set_index(agustus13.pop('TANGGAL'), inplace=True)
agustus13
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-13  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-13  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-13  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-13  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-13  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-13  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-13  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-13  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-13  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-13  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (14 Agustus 2021).xlsx"
agus14=pd.read_excel(path)
agus14.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus14=agus14.loc[1:]
x=datetime(2021,8,14)
agustus14['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus14.set_index(agustus14.pop('TANGGAL'), inplace=True)
agustus14
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-14  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-14  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-14  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-14  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-14  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-14  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-14  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-14  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-14  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-14  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (15 Agustus 2021).xlsx"
agus15=pd.read_excel(path)
agus15.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus15=agus15.loc[1:]
x=datetime(2021,8,15)
agustus15['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus15.set_index(agustus15.pop('TANGGAL'), inplace=True)
agustus15
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-15  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-15  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-15  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-15  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-15  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-15  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-15  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-15  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-15  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-15  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (16 Agustus 2021).xlsx"
agus16=pd.read_excel(path)
agus16.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus16=agus16.loc[1:]
x=datetime(2021,8,16)
agustus16['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus16.set_index(agustus16.pop('TANGGAL'), inplace=True)
agustus16
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-16  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-16  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-16  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-16  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-16  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-16  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-16  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-16  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-16  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-16  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (17 Agustus 2021).xlsx"
agus17=pd.read_excel(path)
agus17.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus17=agus17.loc[1:]
x=datetime(2021,8,17)
agustus17['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus17.set_index(agustus17.pop('TANGGAL'), inplace=True)
agustus17
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-17  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-17  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-17  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-17  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-17  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-17  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-17  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-17  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-17  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-17  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (18 Agustus 2021).xlsx"
agus18=pd.read_excel(path)
agus18.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus18=agus18.loc[1:]
x=datetime(2021,8,18)
agustus18['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus18.set_index(agustus18.pop('TANGGAL'), inplace=True)
agustus18
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-18  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-18  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-18  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-18  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-18  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-18  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-18  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-18  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-18  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-18  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (19 Agustus 2021).xlsx"
agus19=pd.read_excel(path)
agus19.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus19=agus19.loc[1:]
x=datetime(2021,8,19)
agustus19['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus19.set_index(agustus19.pop('TANGGAL'), inplace=True)
agustus19
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-19  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-19  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-19  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-19  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-19  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-19  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-19  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-19  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-19  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-19  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (20 Agustus 2021).xlsx"
agus20=pd.read_excel(path)
agus20.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus20=agus20.loc[1:]
x=datetime(2021,8,20)
agustus20['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus20.set_index(agustus20.pop('TANGGAL'), inplace=True)
agustus20
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-20  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-20  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-20  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-20  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-20  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-20  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-20  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-20  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-20  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-20  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (21 Agustus 2021).xlsx"
agus21=pd.read_excel(path)
agus21.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus21=agus21.loc[1:]
x=datetime(2021,8,21)
agustus21['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus21.set_index(agustus21.pop('TANGGAL'), inplace=True)
agustus21
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-21  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-21  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-21  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-21  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-21  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-21  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-21  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-21  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-21  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-21  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (22 Agustus 2021).xlsx"
agus22=pd.read_excel(path)
agus22.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus22=agus22.loc[1:]
x=datetime(2021,8,22)
agustus22['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus22.set_index(agustus22.pop('TANGGAL'), inplace=True)
agustus22
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-22  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-22  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-22  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-22  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-22  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-22  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-22  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-22  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-22  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-22  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (23 Agustus 2021).xlsx"
agus23=pd.read_excel(path)
agus23.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus23=agus23.loc[1:]
x=datetime(2021,8,23)
agustus23['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus23.set_index(agustus23.pop('TANGGAL'), inplace=True)
agustus23
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-23  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-23  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-23  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-23  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-23  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-23  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-23  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-23  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-23  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-23  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (24 Agustus 2021).xlsx"
agus24=pd.read_excel(path)
agus24.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus24=agus24.loc[1:]
x=datetime(2021,8,24)
agustus24['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus24.set_index(agustus24.pop('TANGGAL'), inplace=True)
agustus24
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-24  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-24  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-24  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-24  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-24  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-24  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-24  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-24  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-24  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-24  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (25 Agustus 2021).xlsx"
agus25=pd.read_excel(path)
agus25.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus25=agus25.loc[1:]
x=datetime(2021,8,25)
agustus25['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus25.set_index(agustus25.pop('TANGGAL'), inplace=True)
agustus25
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-25  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-25  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-25  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-25  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-25  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-25  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-25  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-25  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-25  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-25  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (26 Agustus 2021).xlsx"
agus26=pd.read_excel(path)
agus26.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus26=agus26.loc[1:]
x=datetime(2021,8,26)
agustus26['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus26.set_index(agustus26.pop('TANGGAL'), inplace=True)
agustus26
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-26  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-26  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-26  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-26  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-26  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-26  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-26  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-26  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-26  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-26  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (27 Agustus 2021).xlsx"
agus27=pd.read_excel(path)
agus27.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus27=agus27.loc[1:]
x=datetime(2021,8,27)
agustus27['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus27.set_index(agustus27.pop('TANGGAL'), inplace=True)
agustus27
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-27  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-27  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-27  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-27  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-27  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-27  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-27  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-27  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-27  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-27  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (29 Agustus 2021).xlsx"
agus29=pd.read_excel(path)
agus29.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus29=agus29.loc[1:]
x=datetime(2021,8,29)
agustus29['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus29.set_index(agustus29.pop('TANGGAL'), inplace=True)
agustus29
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-29  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-29  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-29  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-29  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-29  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-29  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-29  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-29  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-29  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-29  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (30 Agustus 2021).xlsx"
agus30=pd.read_excel(path)
agus30.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus30=agus30.loc[1:]
x=datetime(2021,8,30)
agustus30['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus30.set_index(agustus30.pop('TANGGAL'), inplace=True)
agustus30
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-30  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-30  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-30  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-30  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-30  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-30  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-30  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-30  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-30  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-30  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Agustus/Data Vaksinasi Berbasis Kelurahan (31 Agustus 2021).xlsx"
agus31=pd.read_excel(path)
agus31.drop(['KODE KELURAHAN'],axis=1,inplace=True)
agustus31=agus31.loc[1:]
x=datetime(2021,8,31)
agustus31['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
agustus31.set_index(agustus31.pop('TANGGAL'), inplace=True)
agustus31
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-31  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-31  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-31  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-31  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-31  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-31  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-31  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-31  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-31  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-31  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
agustusgabung=pd.concat([agustus1,agustus2,agustus3,agustus4,agustus5,agustus6,agustus7,agustus8,agustus9,agustus10,agustus11,
                         agustus12,agustus13,agustus14,agustus15,agustus16,agustus17,agustus18,agustus19,agustus20,agustus21,
                         agustus22,agustus23,agustus24,agustus25,agustus26,agustus27,agustus29,agustus30,agustus31],axis=0)
agustusgabung
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-08-01  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-08-01  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-08-01  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-08-01  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-08-01  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-08-31  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-08-31  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-08-31  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-08-31  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-08-31  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
agustusgabung.shape
# Out:
# (8010, 26)

# %%
agustusgabung.describe()
# Out:
#              SASARAN  BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# count    8010.000000   8010.000000      8010.000000      8010.000000
# mean    33487.681648  13832.505993     19655.175655      9526.931461
# std     20094.206358   8859.445978     11649.464802      5860.461888
# min      1941.000000    322.000000      1233.000000       626.000000
# 25%     20509.000000   8087.250000     11909.000000      5466.250000
# 50%     30019.000000  12536.500000     17709.500000      8403.000000
# 75%     42308.000000  17746.000000     24995.750000     12582.750000
# max    134466.000000  73501.000000     81857.000000     42273.000000
#
#        TOTAL VAKSIN\nDIBERIKAN  LANSIA\nDOSIS 1  LANSIA\nDOSIS 2  \
# count              8010.000000      8010.000000      8010.000000
# mean              29182.107116      1956.881523      1704.752310
# std               17244.344462      1102.466304       997.770691
# min                1859.000000       118.000000       103.000000
# ...

# %%
agustusgabung.isna().sum()
# Out:
# WILAYAH KOTA                                0
# KECAMATAN                                   0
# KELURAHAN                                   0
# SASARAN                                     0
# BELUM VAKSIN                                0
# JUMLAH\nDOSIS 1                             0
# JUMLAH\nDOSIS 2                             0
# TOTAL VAKSIN\nDIBERIKAN                     0
# LANSIA\nDOSIS 1                             0
# LANSIA\nDOSIS 2                             0
# LANSIA TOTAL \nVAKSIN DIBERIKAN             0
# PELAYAN PUBLIK\nDOSIS 1                     0
# PELAYAN PUBLIK\nDOSIS 2                     0
# PELAYAN PUBLIK TOTAL\nVAKSIN DIBERIKAN      0
# GOTONG ROYONG\nDOSIS 1                      0
# GOTONG ROYONG\nDOSIS 2                      0
# GOTONG ROYONG TOTAL\nVAKSIN DIBERIKAN       0
# TENAGA KESEHATAN\nDOSIS 1                   0
# TENAGA KESEHATAN\nDOSIS 2                   0
# TENAGA KESEHATAN TOTAL\nVAKSIN DIBERIKAN    0
# ...

# %%
agustusgabung.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8010 entries, 2021-08-01 to 2021-08-31
# Data columns (total 26 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   WILAYAH KOTA                             8010 non-null   object
#  1   KECAMATAN                                8010 non-null   object
#  2   KELURAHAN                                8010 non-null   object
#  3   SASARAN                                  8010 non-null   int64
#  4   BELUM VAKSIN                             8010 non-null   int64
#  5   JUMLAH
# DOSIS 1                           8010 non-null   int64
#  6   JUMLAH
# DOSIS 2                           8010 non-null   int64
#  7   TOTAL VAKSIN
# DIBERIKAN                   8010 non-null   int64
#  8   LANSIA
# DOSIS 1                           8010 non-null   int64
#  9   LANSIA
# DOSIS 2                           8010 non-null   int64
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (01 September 2021).xlsx"
sep1=pd.read_excel(path)
sep1.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september1=sep1.loc[1:]
x=datetime(2021,9,1)
september1['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september1.set_index(september1.pop('TANGGAL'), inplace=True)
september1
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-01  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-01  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-01  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-01  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-01  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-01  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-01  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-01  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-01  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-01  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (01 September 2021).xlsx"
sep1=pd.read_excel(path)
sep1.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september1=sep1.loc[1:]
x=datetime(2021,9,1)
september1['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september1.set_index(september1.pop('TANGGAL'), inplace=True)
september1
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-01  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-01  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-01  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-01  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-01  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-01  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-01  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-01  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-01  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-01  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (02 September 2021).xlsx"
sep2=pd.read_excel(path)
sep2.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september2=sep2.loc[1:]
x=datetime(2021,9,2)
september2['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september2.set_index(september2.pop('TANGGAL'), inplace=True)
september2
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-02  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-02  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-02  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-02  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-02  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-02  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-02  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-02  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-02  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-02  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (03 September 2021).xlsx"
sep3=pd.read_excel(path)
sep3.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september3=sep3.loc[1:]
x=datetime(2021,9,3)
september3['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september3.set_index(september3.pop('TANGGAL'), inplace=True)
september3
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-03  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-03  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-03  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-03  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-03  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-03  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-03  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-03  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-03  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-03  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (04 September 2021).xlsx"
sep4=pd.read_excel(path)
sep4.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september4=sep4.loc[1:]
x=datetime(2021,9,4)
september4['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september4.set_index(september4.pop('TANGGAL'), inplace=True)
september4
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-04  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-04  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-04  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-04  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-04  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-04  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-04  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-04  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-04  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-04  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (05 September 2021).xlsx"
sep5=pd.read_excel(path)
sep5.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september5=sep5.loc[1:]
x=datetime(2021,9,5)
september5['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september5.set_index(september5.pop('TANGGAL'), inplace=True)
september5
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-05  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-05  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-05  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-05  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-05  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-05  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-05  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-05  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-05  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-05  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (06 September 2021).xlsx"
sep6=pd.read_excel(path)
sep6.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september6=sep6.loc[1:]
x=datetime(2021,9,6)
september6['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september6.set_index(september6.pop('TANGGAL'), inplace=True)
september6
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-06  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-06  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-06  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-06  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-06  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-06  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-06  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-06  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-06  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-06  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (07 September 2021).xlsx"
sep7=pd.read_excel(path)
sep7.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september7=sep7.loc[1:]
x=datetime(2021,9,7)
september7['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september7.set_index(september7.pop('TANGGAL'), inplace=True)
september7
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-07  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-07  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-07  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-07  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-07  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-07  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-07  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-07  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-07  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-07  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (08 September 2021).xlsx"
sep8=pd.read_excel(path)
sep8.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september8=sep8.loc[1:]
x=datetime(2021,9,8)
september8['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september8.set_index(september8.pop('TANGGAL'), inplace=True)
september8
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-08  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-08  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-08  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-08  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-08  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-08  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-08  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-08  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-08  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-08  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (09 September 2021).xlsx"
sep9=pd.read_excel(path)
sep9.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september9=sep9.loc[1:]
x=datetime(2021,9,9)
september9['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september9.set_index(september9.pop('TANGGAL'), inplace=True)
september9
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-09  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-09  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-09  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-09  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-09  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-09  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-09  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-09  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-09  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-09  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (10 September 2021).xlsx"
sep10=pd.read_excel(path)
sep10.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september10=sep10.loc[1:]
x=datetime(2021,9,10)
september10['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september10.set_index(september10.pop('TANGGAL'), inplace=True)
september10
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-10  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-10  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-10  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-10  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-10  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-10  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-10  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-10  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-10  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-10  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (12 September 2021).xlsx"
sep12=pd.read_excel(path)
sep12.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september12=sep12.loc[1:]
x=datetime(2021,9,12)
september12['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september12.set_index(september12.pop('TANGGAL'), inplace=True)
september12
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-12  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-12  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-12  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-12  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-12  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-12  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-12  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-12  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-12  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-12  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (13 September 2021).xlsx"
sep13=pd.read_excel(path)
sep13.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september13=sep13.loc[1:]
x=datetime(2021,9,13)
september13['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september13.set_index(september13.pop('TANGGAL'), inplace=True)
september13
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-13  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-13  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-13  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-13  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-13  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-13  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-13  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-13  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-13  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-13  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (14 September 2021).xlsx"
sep14=pd.read_excel(path)
sep14.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september14=sep14.loc[1:]
x=datetime(2021,9,14)
september14['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september14.set_index(september14.pop('TANGGAL'), inplace=True)
september14
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-14  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-14  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-14  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-14  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-14  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-14  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-14  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-14  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-14  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-14  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (15 September 2021).xlsx"
sep15=pd.read_excel(path)
sep15.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september15=sep15.loc[1:]
x=datetime(2021,9,15)
september15['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september15.set_index(september15.pop('TANGGAL'), inplace=True)
september15
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-15  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-15  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-15  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-15  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-15  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-15  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-15  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-15  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-15  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-15  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (16 September 2021).xlsx"
sep16=pd.read_excel(path)
sep16.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september16=sep16.loc[1:]
x=datetime(2021,9,16)
september16['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september16.set_index(september16.pop('TANGGAL'), inplace=True)
september16
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-16  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-16  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-16  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-16  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-16  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-16  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-16  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-16  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-16  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-16  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (17 September 2021).xlsx"
sep17=pd.read_excel(path)
sep17.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september17=sep17.loc[1:]
x=datetime(2021,9,17)
september17['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september17.set_index(september17.pop('TANGGAL'), inplace=True)
september17
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-17  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-17  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-17  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-17  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-17  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-17  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-17  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-17  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-17  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-17  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (18 September 2021).xlsx"
sep18=pd.read_excel(path)
sep18.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september18=sep18.loc[1:]
x=datetime(2021,9,18)
september18['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september18.set_index(september18.pop('TANGGAL'), inplace=True)
september18
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-18  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-18  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-18  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-18  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-18  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-18  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-18  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-18  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-18  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-18  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (19 September 2021).xlsx"
sep19=pd.read_excel(path)
sep19.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september19=sep19.loc[1:]
x=datetime(2021,9,19)
september19['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september19.set_index(september19.pop('TANGGAL'), inplace=True)
september19
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-19  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-19  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-19  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-19  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-19  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-19  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-19  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-19  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-19  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-19  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (20 September 2021).xlsx"
sep20=pd.read_excel(path)
sep20.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september20=sep20.loc[1:]
x=datetime(2021,9,20)
september20['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september20.set_index(september20.pop('TANGGAL'), inplace=True)
september20
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-20  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-20  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-20  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-20  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-20  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-20  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-20  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-20  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-20  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-20  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (21 September 2021).xlsx"
sep21=pd.read_excel(path)
sep21.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september21=sep21.loc[1:]
x=datetime(2021,9,21)
september21['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september21.set_index(september21.pop('TANGGAL'), inplace=True)
september21
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-21  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-21  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-21  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-21  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-21  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-21  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-21  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-21  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-21  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-21  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (22 September 2021).xlsx"
sep22=pd.read_excel(path)
sep22.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september22=sep22.loc[1:]
x=datetime(2021,9,22)
september22['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september22.set_index(september22.pop('TANGGAL'), inplace=True)
september22
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-22  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-22  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-22  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-22  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-22  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-22  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-22  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-22  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-22  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-22  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (23 September 2021).xlsx"
sep23=pd.read_excel(path)
sep23.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september23=sep23.loc[1:]
x=datetime(2021,9,23)
september23['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september23.set_index(september23.pop('TANGGAL'), inplace=True)
september23
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-23  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-23  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-23  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-23  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-23  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-23  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-23  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-23  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-23  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-23  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (24 September 2021).xlsx"
sep24=pd.read_excel(path)
sep24.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september24=sep24.loc[1:]
x=datetime(2021,9,24)
september24['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september24.set_index(september24.pop('TANGGAL'), inplace=True)
september24
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-24  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-24  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-24  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-24  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-24  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-24  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-24  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-24  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-24  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-24  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (25 September 2021).xlsx"
sep25=pd.read_excel(path)
sep25.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september25=sep25.loc[1:]
x=datetime(2021,9,25)
september25['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september25.set_index(september25.pop('TANGGAL'), inplace=True)
september25
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-25  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-25  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-25  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-25  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-25  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-25  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-25  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-25  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-25  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-25  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (26 September 2021).xlsx"
sep26=pd.read_excel(path)
sep26.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september26=sep26.loc[1:]
x=datetime(2021,9,26)
september26['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september26.set_index(september26.pop('TANGGAL'), inplace=True)
september26
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-26  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-26  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-26  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-26  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-26  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-26  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-26  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-26  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-26  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-26  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (27 September 2021).xlsx"
sep27=pd.read_excel(path)
sep27.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september27=sep27.loc[1:]
x=datetime(2021,9,27)
september27['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september27.set_index(september27.pop('TANGGAL'), inplace=True)
september27
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-27  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-27  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-27  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-27  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-27  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-27  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-27  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-27  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-27  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-27  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (28 September 2021).xlsx"
sep28=pd.read_excel(path)
sep28.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september28=sep28.loc[1:]
x=datetime(2021,9,28)
september28['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september28.set_index(september28.pop('TANGGAL'), inplace=True)
september28
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-28  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-28  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-28  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-28  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-28  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-28  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-28  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-28  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-28  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-28  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (29 September 2021).xlsx"
sep29=pd.read_excel(path)
sep29.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september29=sep29.loc[1:]
x=datetime(2021,9,29)
september29['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september29.set_index(september29.pop('TANGGAL'), inplace=True)
september29
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-29  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-29  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-29  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-29  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-29  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-29  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-29  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-29  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-29  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-29  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "September/Data Vaksinasi Berbasis Kelurahan (30 September 2021).xlsx"
sep30=pd.read_excel(path)
sep30.drop(['KODE KELURAHAN'],axis=1,inplace=True)
september30=sep30.loc[1:]
x=datetime(2021,9,30)
september30['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
september30.set_index(september30.pop('TANGGAL'), inplace=True)
september30
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-30  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-30  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-30  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-30  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-30  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-30  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-30  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-30  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-30  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-30  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
septembergabung=pd.concat([september1,september2,september3,september4,september5,september6,september7,september8,september9,
                          september10,september12,september13,september14,september15,september16,september17,
                          september18,september19,september20,september21,september22,september23,september24,september25,
                          september26,september27,september28,september29,september30],axis=0)
septembergabung
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-09-01  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-09-01  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-09-01  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-09-01  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-09-01  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-09-30  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-09-30  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-09-30  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-09-30  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-09-30  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
septembergabung.shape
# Out:
# (7743, 26)

# %%
septembergabung.describe()
# Out:
#              SASARAN  BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# count    7743.000000   7743.000000      7743.000000      7743.000000
# mean    33487.681648  10815.382022     22672.299625     16120.466744
# std     20094.249616   6981.856152     13534.493338      9902.673872
# min      1941.000000    222.000000      1452.000000       942.000000
# 25%     20509.000000   6093.500000     13493.000000      9560.500000
# 50%     30019.000000   9607.000000     20626.000000     14366.000000
# 75%     42308.000000  14162.500000     28603.000000     20876.000000
# max    134466.000000  52284.000000     95935.000000     71313.000000
#
#        TOTAL VAKSIN\nDIBERIKAN  LANSIA\nDOSIS 1  LANSIA\nDOSIS 2  \
# count              7743.000000      7743.000000      7743.000000
# mean              38792.766370      2075.962805      1838.962159
# std               23340.489565      1159.558777      1062.034635
# min                2394.000000       119.000000       108.000000
# ...

# %%
septembergabung.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7743 entries, 2021-09-01 to 2021-09-30
# Data columns (total 26 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   WILAYAH KOTA                             7743 non-null   object
#  1   KECAMATAN                                7743 non-null   object
#  2   KELURAHAN                                7743 non-null   object
#  3   SASARAN                                  7743 non-null   int64
#  4   BELUM VAKSIN                             7743 non-null   int64
#  5   JUMLAH
# DOSIS 1                           7743 non-null   int64
#  6   JUMLAH
# DOSIS 2                           7743 non-null   int64
#  7   TOTAL VAKSIN
# DIBERIKAN                   7743 non-null   int64
#  8   LANSIA
# DOSIS 1                           7743 non-null   int64
#  9   LANSIA
# DOSIS 2                           7743 non-null   int64
# ...

# %%
septembergabung.isna().sum()
# Out:
# WILAYAH KOTA                                0
# KECAMATAN                                   0
# KELURAHAN                                   0
# SASARAN                                     0
# BELUM VAKSIN                                0
# JUMLAH\nDOSIS 1                             0
# JUMLAH\nDOSIS 2                             0
# TOTAL VAKSIN\nDIBERIKAN                     0
# LANSIA\nDOSIS 1                             0
# LANSIA\nDOSIS 2                             0
# LANSIA TOTAL \nVAKSIN DIBERIKAN             0
# PELAYAN PUBLIK\nDOSIS 1                     0
# PELAYAN PUBLIK\nDOSIS 2                     0
# PELAYAN PUBLIK TOTAL\nVAKSIN DIBERIKAN      0
# GOTONG ROYONG\nDOSIS 1                      0
# GOTONG ROYONG\nDOSIS 2                      0
# GOTONG ROYONG TOTAL\nVAKSIN DIBERIKAN       0
# TENAGA KESEHATAN\nDOSIS 1                   0
# TENAGA KESEHATAN\nDOSIS 2                   0
# TENAGA KESEHATAN TOTAL\nVAKSIN DIBERIKAN    0
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (01 Oktober 2021).xlsx"
ok1=pd.read_excel(path)
ok1.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto1=ok1.loc[1:]
x=datetime(2021,10,1)
okto1['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto1.set_index(okto1.pop('TANGGAL'), inplace=True)
okto1
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-01  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-01  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-01  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-01  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-01  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-01  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-01  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-01  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-01  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-01  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (02 Oktober 2021).xlsx"
ok2=pd.read_excel(path)
ok2.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto2=ok2.loc[1:]
x=datetime(2021,10,2)
okto2['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto2.set_index(okto2.pop('TANGGAL'), inplace=True)
okto2
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-02  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-02  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-02  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-02  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-02  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-02  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-02  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-02  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-02  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-02  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (03 Oktober 2021).xlsx"
ok3=pd.read_excel(path)
ok3.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto3=ok3.loc[1:]
x=datetime(2021,10,3)
okto3['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto3.set_index(okto3.pop('TANGGAL'), inplace=True)
okto3
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-03  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-03  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-03  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-03  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-03  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-03  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-03  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-03  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-03  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-03  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (04 Oktober 2021).xlsx"
ok4=pd.read_excel(path)
ok4.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto4=ok4.loc[1:]
x=datetime(2021,10,4)
okto4['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto4.set_index(okto4.pop('TANGGAL'), inplace=True)
okto4
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-04  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-04  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-04  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-04  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-04  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-04  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-04  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-04  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-04  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-04  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (05 Oktober 2021).xlsx"
ok5=pd.read_excel(path)
ok5.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto5=ok5.loc[1:]
x=datetime(2021,10,5)
okto5['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto5.set_index(okto5.pop('TANGGAL'), inplace=True)
okto5
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-05  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-05  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-05  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-05  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-05  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-05  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-05  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-05  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-05  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-05  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (06 Oktober 2021).xlsx"
ok6=pd.read_excel(path)
ok6.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto6=ok6.loc[1:]
x=datetime(2021,10,6)
okto6['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto6.set_index(okto6.pop('TANGGAL'), inplace=True)
okto6
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-06  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-06  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-06  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-06  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-06  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-06  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-06  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-06  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-06  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-06  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (07 Oktober 2021).xlsx"
ok7=pd.read_excel(path)
ok7.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto7=ok7.loc[1:]
x=datetime(2021,10,7)
okto7['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto7.set_index(okto7.pop('TANGGAL'), inplace=True)
okto7
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-07  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-07  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-07  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-07  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-07  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-07  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-07  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-07  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-07  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-07  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (08 Oktober 2021).xlsx"
ok8=pd.read_excel(path)
ok8.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto8=ok8.loc[1:]
x=datetime(2021,10,8)
okto8['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto8.set_index(okto8.pop('TANGGAL'), inplace=True)
okto8
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-08  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-08  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-08  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-08  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-08  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-08  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-08  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-08  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-08  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-08  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (09 Oktober 2021).xlsx"
ok9=pd.read_excel(path)
ok9.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto9=ok9.loc[1:]
x=datetime(2021,10,9)
okto9['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto9.set_index(okto9.pop('TANGGAL'), inplace=True)
okto9
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-09  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-09  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-09  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-09  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-09  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-09  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-09  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-09  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-09  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-09  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (10 Oktober 2021).xlsx"
ok10=pd.read_excel(path)
ok10.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto10=ok10.loc[1:]
x=datetime(2021,10,10)
okto10['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto10.set_index(okto10.pop('TANGGAL'), inplace=True)
okto10
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-10  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-10  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-10  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-10  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-10  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-10  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-10  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-10  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-10  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-10  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (11 Oktober 2021).xlsx"
ok11=pd.read_excel(path)
ok11.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto11=ok11.loc[1:]
x=datetime(2021,10,11)
okto11['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto11.set_index(okto11.pop('TANGGAL'), inplace=True)
okto11
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-11  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-11  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-11  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-11  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-11  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-11  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-11  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-11  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-11  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-11  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (12 Oktober 2021).xlsx"
ok12=pd.read_excel(path)
ok12.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto12=ok12.loc[1:]
x=datetime(2021,10,12)
okto12['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto12.set_index(okto12.pop('TANGGAL'), inplace=True)
okto12
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-12  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-12  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-12  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-12  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-12  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-12  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-12  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-12  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-12  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-12  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (13 Oktober 2021).xlsx"
ok13=pd.read_excel(path)
ok13.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto13=ok13.loc[1:]
x=datetime(2021,10,13)
okto13['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto13.set_index(okto13.pop('TANGGAL'), inplace=True)
okto13
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-13  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-13  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-13  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-13  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-13  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-13  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-13  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-13  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-13  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-13  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (14 Oktober 2021).xlsx"
ok14=pd.read_excel(path)
ok14.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto14=ok14.loc[1:]
x=datetime(2021,10,14)
okto14['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto14.set_index(okto14.pop('TANGGAL'), inplace=True)
okto14
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-14  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-14  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-14  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-14  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-14  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-14  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-14  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-14  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-14  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-14  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (15 Oktober 2021).xlsx"
ok15=pd.read_excel(path)
ok15.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto15=ok15.loc[1:]
x=datetime(2021,10,15)
okto15['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto15.set_index(okto15.pop('TANGGAL'), inplace=True)
okto15
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-15  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-15  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-15  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-15  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-15  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-15  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-15  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-15  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-15  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-15  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (16 Oktober 2021).xlsx"
ok16=pd.read_excel(path)
ok16.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto16=ok16.loc[1:]
x=datetime(2021,10,16)
okto16['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto16.set_index(okto16.pop('TANGGAL'), inplace=True)
okto16
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-16  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-16  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-16  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-16  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-16  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-16  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-16  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-16  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-16  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-16  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (17 Oktober 2021).xlsx"
ok17=pd.read_excel(path)
ok17.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto17=ok17.loc[1:]
x=datetime(2021,10,17)
okto17['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto17.set_index(okto17.pop('TANGGAL'), inplace=True)
okto17
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-17  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-17  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-17  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-17  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-17  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-17  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-17  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-17  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-17  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-17  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (18 Oktober 2021).xlsx"
ok18=pd.read_excel(path)
ok18.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto18=ok18.loc[1:]
x=datetime(2021,10,18)
okto18['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto18.set_index(okto18.pop('TANGGAL'), inplace=True)
okto18
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-18  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-18  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-18  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-18  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-18  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-18  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-18  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-18  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-18  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-18  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (19 Oktober 2021).xlsx"
ok19=pd.read_excel(path)
ok19.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto19=ok19.loc[1:]
x=datetime(2021,10,19)
okto19['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto19.set_index(okto19.pop('TANGGAL'), inplace=True)
okto19
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-19  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-19  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-19  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-19  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-19  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-19  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-19  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-19  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-19  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-19  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (20 Oktober 2021).xlsx"
ok20=pd.read_excel(path)
ok20.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto20=ok20.loc[1:]
x=datetime(2021,10,20)
okto20['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto20.set_index(okto20.pop('TANGGAL'), inplace=True)
okto20
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-20  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-20  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-20  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-20  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-20  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-20  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-20  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-20  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-20  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-20  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (21 Oktober 2021).xlsx"
ok21=pd.read_excel(path)
ok21.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto21=ok21.loc[1:]
x=datetime(2021,10,21)
okto21['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto21.set_index(okto21.pop('TANGGAL'), inplace=True)
okto21
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-21  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-21  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-21  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-21  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-21  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-21  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-21  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-21  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-21  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-21  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (22 Oktober 2021).xlsx"
ok22=pd.read_excel(path)
ok22.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto22=ok22.loc[1:]
x=datetime(2021,10,22)
okto22['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto22.set_index(okto22.pop('TANGGAL'), inplace=True)
okto22
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-22  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-22  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-22  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-22  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-22  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-22  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-22  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-22  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-22  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-22  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (23 Oktober 2021).xlsx"
ok23=pd.read_excel(path)
ok23.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto23=ok23.loc[1:]
x=datetime(2021,10,23)
okto23['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto23.set_index(okto23.pop('TANGGAL'), inplace=True)
okto23
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-23  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-23  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-23  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-23  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-23  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-23  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-23  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-23  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-23  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-23  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (24 Oktober 2021).xlsx"
ok24=pd.read_excel(path)
ok24.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto24=ok24.loc[1:]
x=datetime(2021,10,24)
okto24['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto24.set_index(okto24.pop('TANGGAL'), inplace=True)
okto24
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-24  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-24  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-24  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-24  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-24  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-24  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-24  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-24  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-24  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-24  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (25 Oktober 2021).xlsx"
ok25=pd.read_excel(path)
ok25.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto25=ok25.loc[1:]
x=datetime(2021,10,25)
okto25['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto25.set_index(okto25.pop('TANGGAL'), inplace=True)
okto25
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-25  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-25  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-25  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-25  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-25  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-25  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-25  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-25  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-25  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-25  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (26 Oktober 2021).xlsx"
ok26=pd.read_excel(path)
ok26.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto26=ok26.loc[1:]
x=datetime(2021,10,26)
okto26['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto26.set_index(okto26.pop('TANGGAL'), inplace=True)
okto26
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-26  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-26  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-26  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-26  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-26  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-26  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-26  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-26  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-26  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-26  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (27 Oktober 2021).xlsx"
ok27=pd.read_excel(path)
ok27.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto27=ok27.loc[1:]
x=datetime(2021,10,27)
okto27['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto27.set_index(okto27.pop('TANGGAL'), inplace=True)
okto27
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-27  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-27  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-27  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-27  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-27  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-27  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-27  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-27  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-27  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-27  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (28 Oktober 2021).xlsx"
ok28=pd.read_excel(path)
ok28.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto28=ok28.loc[1:]
x=datetime(2021,10,28)
okto28['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto28.set_index(okto28.pop('TANGGAL'), inplace=True)
okto28
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-28  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-28  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-28  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-28  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-28  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-28  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-28  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-28  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-28  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-28  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (29 Oktober 2021).xlsx"
ok29=pd.read_excel(path)
ok29.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto29=ok29.loc[1:]
x=datetime(2021,10,29)
okto29['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto29.set_index(okto29.pop('TANGGAL'), inplace=True)
okto29
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-29  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-29  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-29  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-29  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-29  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-29  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-29  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-29  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-29  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-29  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (30 Oktober 2021).xlsx"
ok30=pd.read_excel(path)
ok30.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto30=ok30.loc[1:]
x=datetime(2021,10,30)
okto30['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto30.set_index(okto30.pop('TANGGAL'), inplace=True)
okto30
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-30  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-30  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-30  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-30  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-30  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-30  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-30  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-30  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-30  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-30  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "Oktober/Data Vaksinasi Berbasis Kelurahan (31 Oktober 2021).xlsx"
ok31=pd.read_excel(path)
ok31.drop(['KODE KELURAHAN'],axis=1,inplace=True)
okto31=ok31.loc[1:]
x=datetime(2021,10,31)
okto31['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
okto31.set_index(okto31.pop('TANGGAL'), inplace=True)
okto31
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-31  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-31  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-31  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-31  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-31  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-31  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-31  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-31  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-31  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-31  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
oktobergabung=pd.concat([okto1,okto2,okto3,okto4,okto5,okto6,okto7,okto8,okto9,okto10,okto11,okto12,okto13,okto14,okto15,
                        okto16,okto17,okto18,okto19,okto20,okto21,okto22,okto23,okto24,okto25,okto26,okto27,okto28,okto29,
                        okto30,okto31],axis=0)
oktobergabung
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-10-01  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-10-01  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-10-01  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-10-01  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-10-01  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-10-31  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-10-31  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-10-31  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-10-31  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-10-31  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
oktobergabung.shape
# Out:
# (8277, 26)

# %%
oktobergabung.describe()
# Out:
#              SASARAN  BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# count    8277.000000   8277.000000      8277.000000      8277.000000
# mean    33487.681648   7581.303733     25906.377915     20495.363779
# std     20094.165891   4969.191572     15296.145571     12060.230795
# min      1941.000000    113.000000      1652.000000      1338.000000
# 25%     20509.000000   4412.000000     15639.000000     12197.000000
# 50%     30019.000000   6819.000000     23718.000000     18542.000000
# 75%     42308.000000   9600.000000     32549.000000     25832.000000
# max    134466.000000  38313.000000    104730.000000     86302.000000
#
#        TOTAL VAKSIN\nDIBERIKAN  LANSIA\nDOSIS 1  LANSIA\nDOSIS 2  \
# count              8277.000000      8277.000000      8277.000000
# mean              46401.741694      2244.557448      1991.180983
# std               27331.875732      1235.331864      1130.885697
# min                2990.000000       119.000000       112.000000
# ...

# %%
oktobergabung.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8277 entries, 2021-10-01 to 2021-10-31
# Data columns (total 26 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   WILAYAH KOTA                             8277 non-null   object
#  1   KECAMATAN                                8277 non-null   object
#  2   KELURAHAN                                8277 non-null   object
#  3   SASARAN                                  8277 non-null   int64
#  4   BELUM VAKSIN                             8277 non-null   int64
#  5   JUMLAH
# DOSIS 1                           8277 non-null   int64
#  6   JUMLAH
# DOSIS 2                           8277 non-null   int64
#  7   TOTAL VAKSIN
# DIBERIKAN                   8277 non-null   int64
#  8   LANSIA
# DOSIS 1                           8277 non-null   int64
#  9   LANSIA
# DOSIS 2                           8277 non-null   int64
# ...

# %%
oktobergabung.isna().sum()
# Out:
# WILAYAH KOTA                                0
# KECAMATAN                                   0
# KELURAHAN                                   0
# SASARAN                                     0
# BELUM VAKSIN                                0
# JUMLAH\nDOSIS 1                             0
# JUMLAH\nDOSIS 2                             0
# TOTAL VAKSIN\nDIBERIKAN                     0
# LANSIA\nDOSIS 1                             0
# LANSIA\nDOSIS 2                             0
# LANSIA TOTAL \nVAKSIN DIBERIKAN             0
# PELAYAN PUBLIK\nDOSIS 1                     0
# PELAYAN PUBLIK\nDOSIS 2                     0
# PELAYAN PUBLIK TOTAL\nVAKSIN DIBERIKAN      0
# GOTONG ROYONG\nDOSIS 1                      0
# GOTONG ROYONG\nDOSIS 2                      0
# GOTONG ROYONG TOTAL\nVAKSIN DIBERIKAN       0
# TENAGA KESEHATAN\nDOSIS 1                   0
# TENAGA KESEHATAN\nDOSIS 2                   0
# TENAGA KESEHATAN TOTAL\nVAKSIN DIBERIKAN    0
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (01 November 2021).xlsx"
no1=pd.read_excel(path)
no1.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov1=no1.loc[1:]
x=datetime(2021,11,1)
nov1['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov1.set_index(nov1.pop('TANGGAL'), inplace=True)
nov1
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-01  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-01  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-01  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-01  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-01  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-01  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-01  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-01  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-01  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-01  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (02 November 2021).xlsx"
no2=pd.read_excel(path)
no2.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov2=no2.loc[1:]
x=datetime(2021,11,2)
nov2['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov2.set_index(nov2.pop('TANGGAL'), inplace=True)
nov2
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-02  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-02  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-02  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-02  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-02  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-02  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-02  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-02  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-02  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-02  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (03 November 2021).xlsx"
no3=pd.read_excel(path)
no3.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov3=no3.loc[1:]
x=datetime(2021,11,3)
nov3['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov3.set_index(nov3.pop('TANGGAL'), inplace=True)
nov3
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-03  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-03  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-03  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-03  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-03  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-03  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-03  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-03  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-03  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-03  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (04 November 2021).xlsx"
no4=pd.read_excel(path)
no4.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov4=no4.loc[1:]
x=datetime(2021,11,4)
nov4['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov4.set_index(nov4.pop('TANGGAL'), inplace=True)
nov4
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-04  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-04  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-04  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-04  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-04  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-04  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-04  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-04  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-04  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-04  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (05 November 2021).xlsx"
no5=pd.read_excel(path)
no5.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov5=no5.loc[1:]
x=datetime(2021,11,5)
nov5['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov5.set_index(nov5.pop('TANGGAL'), inplace=True)
nov5
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-05  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-05  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-05  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-05  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-05  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-05  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-05  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-05  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-05  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-05  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (06 November 2021).xlsx"
no6=pd.read_excel(path)
no6.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov6=no6.loc[1:]
x=datetime(2021,11,6)
nov6['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov6.set_index(nov6.pop('TANGGAL'), inplace=True)
nov6
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-06  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-06  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-06  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-06  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-06  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-06  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-06  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-06  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-06  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-06  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (07 November 2021).xlsx"
no7=pd.read_excel(path)
no7.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov7=no7.loc[1:]
x=datetime(2021,11,7)
nov7['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov7.set_index(nov7.pop('TANGGAL'), inplace=True)
nov7
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-07  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-07  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-07  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-07  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-07  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-07  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-07  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-07  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-07  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-07  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (08 November 2021).xlsx"
no8=pd.read_excel(path)
no8.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov8=no8.loc[1:]
x=datetime(2021,11,8)
nov8['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov8.set_index(nov8.pop('TANGGAL'), inplace=True)
nov8
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-08  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-08  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-08  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-08  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-08  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-08  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-08  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-08  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-08  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-08  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (09 November 2021).xlsx"
no9=pd.read_excel(path)
no9.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov9=no9.loc[1:]
x=datetime(2021,11,9)
nov9['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov9.set_index(nov9.pop('TANGGAL'), inplace=True)
nov9
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-09  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-09  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-09  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-09  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-09  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-09  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-09  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-09  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-09  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-09  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (10 November 2021).xlsx"
no10=pd.read_excel(path)
no10.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov10=no10.loc[1:]
x=datetime(2021,11,10)
nov10['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov10.set_index(nov10.pop('TANGGAL'), inplace=True)
nov10
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-10  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-10  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-10  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-10  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-10  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-10  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-10  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-10  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-10  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-10  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (11 November 2021).xlsx"
no11=pd.read_excel(path)
no11.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov11=no11.loc[1:]
x=datetime(2021,11,11)
nov11['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov11.set_index(nov11.pop('TANGGAL'), inplace=True)
nov11
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-11  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-11  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-11  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-11  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-11  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-11  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-11  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-11  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-11  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-11  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (12 November 2021).xlsx"
no12=pd.read_excel(path)
no12.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov12=no12.loc[1:]
x=datetime(2021,11,12)
nov12['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov12.set_index(nov12.pop('TANGGAL'), inplace=True)
nov12
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-12  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-12  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-12  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-12  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-12  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-12  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-12  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-12  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-12  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-12  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (13 November 2021).xlsx"
no13=pd.read_excel(path)
no13.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov13=no13.loc[1:]
x=datetime(2021,11,13)
nov13['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov13.set_index(nov13.pop('TANGGAL'), inplace=True)
nov13
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-13  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-13  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-13  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-13  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-13  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-13  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-13  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-13  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-13  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-13  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (14 November 2021).xlsx"
no14=pd.read_excel(path)
no14.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov14=no14.loc[1:]
x=datetime(2021,11,14)
nov14['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov14.set_index(nov14.pop('TANGGAL'), inplace=True)
nov14
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-14  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-14  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-14  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-14  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-14  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-14  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-14  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-14  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-14  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-14  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (15 November 2021).xlsx"
no15=pd.read_excel(path)
no15.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov15=no15.loc[1:]
x=datetime(2021,11,15)
nov15['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov15.set_index(nov15.pop('TANGGAL'), inplace=True)
nov15
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-15  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-15  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-15  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-15  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-15  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-15  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-15  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-15  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-15  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-15  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (16 November 2021).xlsx"
no16=pd.read_excel(path)
no16.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov16=no16.loc[1:]
x=datetime(2021,11,16)
nov16['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov16.set_index(nov16.pop('TANGGAL'), inplace=True)
nov16
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-16  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-16  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-16  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-16  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-16  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-16  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-16  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-16  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-16  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-16  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (17 November 2021).xlsx"
no17=pd.read_excel(path)
no17.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov17=no17.loc[1:]
x=datetime(2021,11,17)
nov17['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov17.set_index(nov17.pop('TANGGAL'), inplace=True)
nov17
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-17  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-17  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-17  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-17  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-17  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-17  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-17  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-17  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-17  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-17  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (18 November 2021).xlsx"
no18=pd.read_excel(path)
no18.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov18=no18.loc[1:]
x=datetime(2021,11,18)
nov18['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov18.set_index(nov18.pop('TANGGAL'), inplace=True)
nov18
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-18  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-18  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-18  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-18  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-18  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-18  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-18  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-18  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-18  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-18  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (19 November 2021).xlsx"
no19=pd.read_excel(path)
no19.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov19=no19.loc[1:]
x=datetime(2021,11,19)
nov19['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov19.set_index(nov19.pop('TANGGAL'), inplace=True)
nov19
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-19  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-19  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-19  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-19  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-19  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-19  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-19  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-19  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-19  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-19  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (20 November 2021).xlsx"
no20=pd.read_excel(path)
no20.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov20=no20.loc[1:]
x=datetime(2021,11,20)
nov20['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov20.set_index(nov20.pop('TANGGAL'), inplace=True)
nov20
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-20  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-20  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-20  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-20  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-20  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-20  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-20  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-20  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-20  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-20  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (21 November 2021).xlsx"
no21=pd.read_excel(path)
no21.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov21=no21.loc[1:]
x=datetime(2021,11,21)
nov21['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov21.set_index(nov21.pop('TANGGAL'), inplace=True)
nov21
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-21  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-21  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-21  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-21  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-21  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-21  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-21  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-21  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-21  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-21  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (22 November 2021).xlsx"
no22=pd.read_excel(path)
no22.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov22=no22.loc[1:]
x=datetime(2021,11,22)
nov22['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov22.set_index(nov22.pop('TANGGAL'), inplace=True)
nov22
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-22  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-22  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-22  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-22  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-22  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-22  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-22  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-22  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-22  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-22  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (23 November 2021).xlsx"
no23=pd.read_excel(path)
no23.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov23=no23.loc[1:]
x=datetime(2021,11,23)
nov23['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov23.set_index(nov23.pop('TANGGAL'), inplace=True)
nov23
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-23  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-23  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-23  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-23  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-23  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-23  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-23  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-23  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-23  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-23  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (24 November 2021).xlsx"
no24=pd.read_excel(path)
no24.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov24=no24.loc[1:]
x=datetime(2021,11,24)
nov24['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov24.set_index(nov24.pop('TANGGAL'), inplace=True)
nov24
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-24  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-24  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-24  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-24  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-24  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-24  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-24  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-24  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-24  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-24  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (25 November 2021).xlsx"
no25=pd.read_excel(path)
no25.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov25=no25.loc[1:]
x=datetime(2021,11,25)
nov25['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov25.set_index(nov25.pop('TANGGAL'), inplace=True)
nov25
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-25  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-25  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-25  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-25  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-25  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-25  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-25  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-25  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-25  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-25  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (26 November 2021).xlsx"
no26=pd.read_excel(path)
no26.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov26=no26.loc[1:]
x=datetime(2021,11,26)
nov26['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov26.set_index(nov26.pop('TANGGAL'), inplace=True)
nov26
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-26  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-26  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-26  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-26  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-26  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-26  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-26  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-26  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-26  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-26  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (27 November 2021).xlsx"
no27=pd.read_excel(path)
no27.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov27=no27.loc[1:]
x=datetime(2021,11,27)
nov27['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov27.set_index(nov27.pop('TANGGAL'), inplace=True)
nov27
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-27  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-27  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-27  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-27  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-27  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-27  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-27  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-27  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-27  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-27  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (28 November 2021).xlsx"
no28=pd.read_excel(path)
no28.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov28=no28.loc[1:]
x=datetime(2021,11,28)
nov28['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov28.set_index(nov28.pop('TANGGAL'), inplace=True)
nov28
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-28  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-28  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-28  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-28  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-28  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-28  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-28  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-28  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-28  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-28  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (29 November 2021).xlsx"
no29=pd.read_excel(path)
no29.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov29=no29.loc[1:]
x=datetime(2021,11,29)
nov29['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov29.set_index(nov29.pop('TANGGAL'), inplace=True)
nov29
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-29  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-29  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-29  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-29  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-29  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-29  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-29  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-29  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-29  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-29  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
path = "November/Data Vaksinasi Berbasis Kelurahan (30 November 2021).xlsx"
no30=pd.read_excel(path)
no30.drop(['KODE KELURAHAN'],axis=1,inplace=True)
nov30=no30.loc[1:]
x=datetime(2021,11,30)
nov30['TANGGAL'] = pd.to_datetime(x.strftime("%Y-%m-%d"))
nov30.set_index(nov30.pop('TANGGAL'), inplace=True)
nov30
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-30  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-30  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-30  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-30  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-30  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-30  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-30  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-30  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-30  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-30  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
novembergabung=pd.concat([nov1,nov2,nov3,nov4,nov5,nov6,nov7,nov8,nov8,nov10,nov11,nov12,nov13,nov14,nov15,nov16,nov17,nov18,
                         nov19,nov20,nov21,nov22,nov23,nov24,nov25,nov26,nov27,nov28,nov29,nov30],axis=0)
novembergabung
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-11-01  JAKARTA UTARA         PADEMANGAN              ANCOL    23947
# 2021-11-01  JAKARTA BARAT            TAMBORA              ANGKE    29381
# 2021-11-01  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    29074
# 2021-11-01  JAKARTA TIMUR         JATINEGARA        BALI MESTER     9752
# 2021-11-01  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    26285
# ...                   ...                ...                ...      ...
# 2021-11-30  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-30  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-30  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-30  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-30  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
novembergabung.shape
# Out:
# (8010, 26)

# %%
novembergabung.describe()
# Out:
#              SASARAN  BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# count    8010.000000   8010.000000      8010.000000      8010.000000
# mean    33487.681648   6706.566292     26781.115356     22361.749563
# std     20094.206358   4388.094276     15832.760846     13139.765073
# min      1941.000000    155.000000      1729.000000      1473.000000
# 25%     20509.000000   3875.500000     16288.500000     13335.250000
# 50%     30019.000000   6045.000000     24564.500000     20289.000000
# 75%     42308.000000   8527.750000     33585.500000     28197.750000
# max    134466.000000  33688.000000    103582.000000     86521.000000
#
#        TOTAL VAKSIN\nDIBERIKAN  LANSIA\nDOSIS 1  LANSIA\nDOSIS 2  \
# count              8010.000000      8010.000000      8010.000000
# mean              49142.864919      2311.023596      2085.183770
# std               28951.524932      1263.985352      1171.132066
# min                3202.000000       119.000000       113.000000
# ...

# %%
novembergabung.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8010 entries, 2021-11-01 to 2021-11-30
# Data columns (total 26 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   WILAYAH KOTA                             8010 non-null   object
#  1   KECAMATAN                                8010 non-null   object
#  2   KELURAHAN                                8010 non-null   object
#  3   SASARAN                                  8010 non-null   int64
#  4   BELUM VAKSIN                             8010 non-null   int64
#  5   JUMLAH
# DOSIS 1                           8010 non-null   int64
#  6   JUMLAH
# DOSIS 2                           8010 non-null   int64
#  7   TOTAL VAKSIN
# DIBERIKAN                   8010 non-null   int64
#  8   LANSIA
# DOSIS 1                           8010 non-null   int64
#  9   LANSIA
# DOSIS 2                           8010 non-null   int64
# ...

# %%
novembergabung.isna().sum()
# Out:
# WILAYAH KOTA                                0
# KECAMATAN                                   0
# KELURAHAN                                   0
# SASARAN                                     0
# BELUM VAKSIN                                0
# JUMLAH\nDOSIS 1                             0
# JUMLAH\nDOSIS 2                             0
# TOTAL VAKSIN\nDIBERIKAN                     0
# LANSIA\nDOSIS 1                             0
# LANSIA\nDOSIS 2                             0
# LANSIA TOTAL \nVAKSIN DIBERIKAN             0
# PELAYAN PUBLIK\nDOSIS 1                     0
# PELAYAN PUBLIK\nDOSIS 2                     0
# PELAYAN PUBLIK TOTAL\nVAKSIN DIBERIKAN      0
# GOTONG ROYONG\nDOSIS 1                      0
# GOTONG ROYONG\nDOSIS 2                      0
# GOTONG ROYONG TOTAL\nVAKSIN DIBERIKAN       0
# TENAGA KESEHATAN\nDOSIS 1                   0
# TENAGA KESEHATAN\nDOSIS 2                   0
# TENAGA KESEHATAN TOTAL\nVAKSIN DIBERIKAN    0
# ...

# %%
data=pd.concat([juligabung,agustusgabung,septembergabung,oktobergabung,novembergabung],axis=0)
data
# Out:
#              WILAYAH KOTA          KECAMATAN          KELURAHAN  SASARAN  \
# TANGGAL
# 2021-07-01  JAKARTA UTARA         PADEMANGAN              ANCOL    20393
# 2021-07-01  JAKARTA BARAT            TAMBORA              ANGKE    25785
# 2021-07-01  JAKARTA TIMUR        KRAMAT JATI       BALE KAMBANG    25158
# 2021-07-01  JAKARTA TIMUR         JATINEGARA        BALI MESTER     8683
# 2021-07-01  JAKARTA TIMUR           CIPAYUNG         BAMBU APUS    22768
# ...                   ...                ...                ...      ...
# 2021-11-30  JAKARTA TIMUR           MATRAMAN  UTAN KAYU SELATAN    33511
# 2021-11-30  JAKARTA TIMUR           MATRAMAN    UTAN KAYU UTARA    28169
# 2021-11-30  JAKARTA PUSAT          KEMAYORAN       UTAN PANJANG    29208
# 2021-11-30  JAKARTA UTARA      TANJUNG PRIOK            WARAKAS    44401
# 2021-11-30  JAKARTA BARAT  GROGOL PETAMBURAN      WIJAYA KUSUMA    38934
#
#             BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# TANGGAL
# ...

# %%
data.shape
# Out:
# (39783, 26)

# %%
data.describe()
# Out:
#              SASARAN  BELUM VAKSIN  JUMLAH\nDOSIS 1  JUMLAH\nDOSIS 2  \
# count   39783.000000  39783.000000     39783.000000     39783.000000
# mean    33354.151899  11640.481236     21713.471810     14752.116658
# std     20007.096668   9328.993521     14086.876964     11669.257865
# min      1665.000000    113.000000       921.000000       558.000000
# 25%     20382.000000   5375.500000     11812.000000      5756.000000
# 50%     30003.000000   9151.000000     19262.000000     11954.000000
# 75%     42179.000000  15348.000000     28582.000000     20638.500000
# max    137086.000000  91239.000000    104730.000000     86521.000000
#
#        TOTAL VAKSIN\nDIBERIKAN  LANSIA\nDOSIS 1  LANSIA\nDOSIS 2  \
# count             39783.000000     39783.000000     39783.000000
# mean              36465.588467      2098.155393      1859.487319
# std               25352.252602      1184.912588      1086.064134
# min                1489.000000       118.000000       103.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 39783 entries, 2021-07-01 to 2021-11-30
# Data columns (total 26 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   WILAYAH KOTA                             39783 non-null  object
#  1   KECAMATAN                                39783 non-null  object
#  2   KELURAHAN                                39783 non-null  object
#  3   SASARAN                                  39783 non-null  int64
#  4   BELUM VAKSIN                             39783 non-null  int64
#  5   JUMLAH
# DOSIS 1                           39783 non-null  int64
#  6   JUMLAH
# DOSIS 2                           39783 non-null  int64
#  7   TOTAL VAKSIN
# DIBERIKAN                   39783 non-null  int64
#  8   LANSIA
# DOSIS 1                           39783 non-null  int64
#  9   LANSIA
# DOSIS 2                           39783 non-null  int64
# ...

# %%
data.isna().sum()
# Out:
# WILAYAH KOTA                                   0
# KECAMATAN                                      0
# KELURAHAN                                      0
# SASARAN                                        0
# BELUM VAKSIN                                   0
# JUMLAH\nDOSIS 1                                0
# JUMLAH\nDOSIS 2                                0
# TOTAL VAKSIN\nDIBERIKAN                        0
# LANSIA\nDOSIS 1                                0
# LANSIA\nDOSIS 2                                0
# LANSIA TOTAL \nVAKSIN DIBERIKAN                0
# PELAYAN PUBLIK\nDOSIS 1                        0
# PELAYAN PUBLIK\nDOSIS 2                        0
# PELAYAN PUBLIK TOTAL\nVAKSIN DIBERIKAN         0
# GOTONG ROYONG\nDOSIS 1                         0
# GOTONG ROYONG\nDOSIS 2                         0
# GOTONG ROYONG TOTAL\nVAKSIN DIBERIKAN          0
# TENAGA KESEHATAN\nDOSIS 1                      0
# TENAGA KESEHATAN\nDOSIS 2                      0
# ...

# %%
data.to_excel('data.xlsx', index=False)

# %%
data.to_excel('data1.xlsx')

# %%
data.to_csv('data.csv', index=False)

# %%
data.to_csv('data1.csv')

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
plt.figure(figsize = (50,50))
data.plot.area("KELURAHAN",["JUMLAH\nDOSIS 1", "TOTAL VAKSIN\nDIBERIKAN",])
plt.show()

# %%
plt.figure(figsize = (10,10))
plt.xlabel("KELURAHAN")
plt.title("TOTAL VAKSIN\nDIBERIKAN")
plt.bar("KELURAHAN","TOTAL VAKSIN\nDIBERIKAN",data=data)
plt.show()
